# %% [markdown]
# # Node Classification with Graph Neural Networks
#
# **Author:** [Khalid Salama](https://www.linkedin.com/in/khalid-salama-24403144/)<br>
# **Date created:** 2021/05/30<br>
# **Last modified:** 2021/05/30<br>
# **Description:** Implementing a graph neural network model for predicting the topic of a paper given its citations.

# %% [markdown]
# ## Introduction
#
# Many datasets in various machine learning (ML) applications have structural relationships
# between their entities, which can be represented as graphs. Such application includes
# social and communication networks analysis, traffic prediction, and fraud detection.
# [Graph representation Learning](https://www.cs.mcgill.ca/~wlh/grl_book/)
# aims to build and train models for graph datasets to be used for a variety of ML tasks.
#
# This example demonstrate a simple implementation of a [Graph Neural Network](https://arxiv.org/pdf/1901.00596.pdf)
# (GNN) model. The model is used for a node prediction task on the [Cora dataset](https://relational.fit.cvut.cz/dataset/CORA)
# to predict the subject of a paper given its words and citations network.
#
# Note that, **we implement a Graph Convolution Layer from scratch** to provide better
# understanding of how they work. However, there is a number of specialized TensorFlow-based
# libraries that provide rich GNN APIs, such as [Spectral](https://graphneural.network/),
# [StellarGraph](https://stellargraph.readthedocs.io/en/stable/README.html), and
# [GraphNets](https://github.com/deepmind/graph_nets).

# %% [markdown]
# ## Setup

# %%
import os
import pandas as pd
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics

# %% [markdown]
# ## Prepare the Dataset
#
# The Cora dataset consists of 2,708 scientific papers classified into one of seven classes.
# The citation network consists of 5,429 links. Each paper has a binary word vector of size
# 1,433, indicating the presence of a corresponding word.
#
# ### Download the dataset
#
# The dataset has two tap-separated files: `cora.cites` and `cora.content`.
#
# 1. The `cora.cites` includes the citation records with two columns:
# `cited_paper_id` (target) and `citing_paper_id` (source).
# 2. The `cora.content` includes the paper content records with 1,435 columns:
# `paper_id`, `subject`, and 1,433 binary features.
#
# Let's download the dataset.

# %%
zip_file = keras.utils.get_file(
    fname="cora.tgz",
    origin="https://linqs-data.soe.ucsc.edu/public/lbc/cora.tgz",
    extract=True,
)
data_dir = os.path.join(os.path.dirname(zip_file), "cora")
# Out:
# Downloading data from https://linqs-data.soe.ucsc.edu/public/lbc/cora.tgz
# 172032/168052 [==============================] - 0s 1us/step
# 180224/168052 [================================] - 0s 1us/step

# %% [markdown]
# ### Process and visualize the dataset
#
# Then we load the citations data into a Pandas DataFrame.

# %%
citations = pd.read_csv(
    os.path.join(data_dir, "cora.cites"),
    sep="\t",
    header=None,
    names=["target", "source"],
)
print("Citations shape:", citations.shape)
# Out:
# Citations shape: (5429, 2)

# %% [markdown]
# Now we display a sample of the `citations` DataFrame.
# The `target` column includes the paper ids cited by the paper ids in the `source` column.

# %%
citations.sample(frac=1).head()
# Out:
#       target   source
# 2161   18777   103537
# 5204  643221  1131312
# 1651    9708   181782
# 2649   28504  1139928
# 4187  135464     8581

# %% [markdown]
# Now let's load the papers data into a Pandas DataFrame.

# %%
column_names = ["paper_id"] + [f"term_{idx}" for idx in range(1433)] + ["subject"]
papers = pd.read_csv(
    os.path.join(data_dir, "cora.content"), sep="\t", header=None, names=column_names,
)
print("Papers shape:", papers.shape)
papers = papers.sort_values(by = 'paper_id')
# Out:
# Papers shape: (2708, 1435)

# %% [markdown]
# Now we display a sample of the `papers` DataFrame. The DataFrame includes the `paper_id`
# and the `subject` columns, as well as 1,433 binary column representing whether a term exists
# in the paper or not.

# %%
print(papers.sample(5).T)

# %% [markdown]
# Let's display the count of the papers in each subject.

# %%
print(papers.subject.value_counts())

# %% [markdown]
# We convert the paper ids and the subjects into zero-based indices.

# %%
class_values = sorted(papers["subject"].unique())
class_idx = {name: id for id, name in enumerate(class_values)}
paper_idx = {name: idx for idx, name in enumerate(sorted(papers["paper_id"].unique()))}

papers["paper_id"] = papers["paper_id"].apply(lambda name: paper_idx[name])
citations["source"] = citations["source"].apply(lambda name: paper_idx[name])
citations["target"] = citations["target"].apply(lambda name: paper_idx[name])
papers["subject"] = papers["subject"].apply(lambda value: class_idx[value])

# %%
features
# Out:
#       node  degree_centrality  ...  clustering  subject
# 0        0           0.062431  ...    0.006164        2
# 1        1           0.001478  ...    0.000000        5
# 2        2           0.015515  ...    0.010453        4
# 3        3           0.006280  ...    0.018382        4
# 4        4           0.002955  ...    0.107143        3
# ...    ...                ...  ...         ...      ...
# 2703  2703           0.000369  ...    0.000000        1
# 2704  2704           0.000369  ...    0.000000        1
# 2705  2705           0.001108  ...    0.500000        1
# 2706  2706           0.001108  ...    0.333333        0
# 2707  2707           0.001108  ...    0.166667        2
#
# [2708 rows x 13 columns]

# %% [markdown]
# Now let's visualize the citation graph. Each node in the graph represents a paper,
# and the color of the node corresponds to its subject. Note that we only show a sample of
# the papers in the dataset.

# %%
plt.figure(figsize=(10, 10))
colors = papers["subject"].tolist()
cora_graph = nx.from_pandas_edgelist(citations.sample(n=1500))
subjects = list(papers[papers["paper_id"].isin(list(cora_graph.nodes))]["subject"])
nx.draw_spring(cora_graph, node_size=15, node_color=subjects)

# %% [markdown]
# ### Split the dataset into stratified train and test sets

# %%
train_data, test_data = [], []

for _, group_data in papers.groupby("subject"):
    # Select around 50% of the dataset for training.
    random_selection = np.random.rand(len(group_data.index)) <= 0.77
    train_data.append(group_data[random_selection])
    test_data.append(group_data[~random_selection])

train_data = pd.concat(train_data).sample(frac=1)
test_data = pd.concat(test_data).sample(frac=1)

print("Train data shape:", train_data.shape)
print("Test data shape:", test_data.shape)
# Out:
# Train data shape: (2133, 1435)
# Test data shape: (575, 1435)

# %%
G = nx.DiGraph()
G.add_nodes_from(np.unique(papers['paper_id']))
for i in range(citations.shape[0]):
  G.add_edge(citations.iloc[i]['source'], citations.iloc[i]['target'])

# %%
features = pd.DataFrame(columns={"node"})
# degree_centrality = nx.degree_centrality(G)
# features['node'] = degree_centrality.keys()
features['node'] = np.union1d(np.unique(citations['source']), np.unique(citations['target']))
features.insert(features.shape[1],"degree_centrality", nx.degree_centrality(G).values())
features.insert(features.shape[1],"in_degree_centrality", nx.in_degree_centrality(G).values())
features.insert(features.shape[1],"out_degree_centrality", nx.out_degree_centrality(G).values())
features.insert(features.shape[1],"average_neighbor_degree", nx.average_neighbor_degree(G).values())
features.insert(features.shape[1],"eigenvector_centrality", nx.eigenvector_centrality(G).values())
features.insert(features.shape[1],"closeness_centrality", nx.closeness_centrality(G).values())
# features.insert(features.shape[1],"current_flow_closeness_centrality", nx.current_flow_closeness_centrality(G).values())
features.insert(features.shape[1],"betweenness_centrality", nx.betweenness_centrality(G).values())
# features.insert(features.shape[1],"current_flow_betweenness_centrality", nx.current_flow_betweenness_centrality(G).values())
features.insert(features.shape[1],"load_centrality", nx.load_centrality(G).values())
features.insert(features.shape[1],"harmonic_centrality", nx.harmonic_centrality(G).values())
# features.insert(features.shape[1],"second_order_centrality", nx.second_order_centrality(G).values())
features.insert(features.shape[1],"pagerank", nx.pagerank(G, alpha = 0.8).values())
features.insert(features.shape[1],"clustering", nx.clustering(G).values())
features.insert(features.shape[1],"subject", papers['subject'].astype('int'))

# %%
X = features.to_numpy()[:, 1:12]
Y = features.to_numpy()[:, 12]
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.33, random_state=42)

model = RandomForestClassifier(max_depth=10, random_state=0)
model.fit(x_train, y_train)
y_pred=model.predict(x_test)
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.27740492170022374

# %%
X_all = pd.concat([features, papers], axis=1).drop(['paper_id', 'subject', 'node'], axis=1).to_numpy()
Y_all = features.to_numpy()[:, 12]
x_train_all, x_test_all, y_train_all, y_test_all = train_test_split(X_all, Y_all, test_size=0.33, random_state=42)

model = RandomForestClassifier(max_depth=10, random_state=0)
model.fit(x_train_all, y_train_all)
y_pred=model.predict(x_test_all)
print("Accuracy:",metrics.accuracy_score(y_test_all, y_pred))
# Out:
# Accuracy: 0.598434004474273

# %% [markdown]
# ## Implement Train and Evaluate Experiment

# %%
hidden_units = [32, 32]
learning_rate = 0.01
dropout_rate = 0.5
num_epochs = 300
batch_size = 256

# %% [markdown]
# This function compiles and trains an input model using the given training data.

# %%
def run_experiment(model, x_train, y_train):
    # Compile the model.
    model.compile(
        optimizer=keras.optimizers.Adam(learning_rate),
        loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
        metrics=[keras.metrics.SparseCategoricalAccuracy(name="acc")],
    )
    # Create an early stopping callback.
    early_stopping = keras.callbacks.EarlyStopping(
        monitor="val_acc", patience=50, restore_best_weights=True
    )
    # Fit the model.
    history = model.fit(
        x=x_train,
        y=y_train,
        epochs=num_epochs,
        batch_size=batch_size,
        validation_split=0.15,
        callbacks=[early_stopping],
    )

    return history

# %% [markdown]
# This function displays the loss and accuracy curves of the model during training.

# %%
def display_learning_curves(history):
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))

    ax1.plot(history.history["loss"])
    ax1.plot(history.history["val_loss"])
    ax1.legend(["train", "test"], loc="upper right")
    ax1.set_xlabel("Epochs")
    ax1.set_ylabel("Loss")

    ax2.plot(history.history["acc"])
    ax2.plot(history.history["val_acc"])
    ax2.legend(["train", "test"], loc="upper right")
    ax2.set_xlabel("Epochs")
    ax2.set_ylabel("Accuracy")
    plt.show()

# %% [markdown]
# ## Implement Feedforward Network (FFN) Module
#
# We will use this module in the baseline and the GNN models.

# %%
def create_ffn(hidden_units, dropout_rate, name=None):
    fnn_layers = []

    for units in hidden_units:
        fnn_layers.append(layers.BatchNormalization())
        fnn_layers.append(layers.Dropout(dropout_rate))
        fnn_layers.append(layers.Dense(units, activation=tf.nn.gelu))

    return keras.Sequential(fnn_layers, name=name)

# %% [markdown]
# ## Build a Baseline Neural Network Model
#
# ### Prepare the data for the baseline model

# %%
feature_names = set(papers.columns) - {"paper_id", "subject"}
num_features = len(feature_names)
num_classes = len(class_idx)

# Create train and test features as a numpy array.
X_train = train_data[feature_names].to_numpy()
X_test = test_data[feature_names].to_numpy()
# Create train and test targets as a numpy array.
Y_train = train_data["subject"]
Y_test = test_data["subject"]

# %% [markdown]
# ### Implement a baseline classifier
#
# We add five FFN blocks with skip connections, so that we generate a baseline model with
# roughly the same number of parameters as the GNN models to be built later.

# %%
def create_baseline_model(hidden_units, num_classes, dropout_rate=0.2):
    inputs = layers.Input(shape=(num_features,), name="input_features")
    x = create_ffn(hidden_units, dropout_rate, name=f"ffn_block1")(inputs)
    for block_idx in range(8):
        # Create an FFN block.
        x1 = create_ffn(hidden_units, dropout_rate, name=f"ffn_block{block_idx + 2}")(x)
        # Add skip connection.
        x = layers.Add(name=f"skip_connection{block_idx + 2}")([x, x1])
    # Compute logits.
    logits = layers.Dense(num_classes, name="logits")(x)
    # Create the model.
    return keras.Model(inputs=inputs, outputs=logits, name="baseline")

# %% [markdown]
# ### Train the baseline classifier

# %%
num_features = 11
baseline_model = create_baseline_model(hidden_units, num_classes, dropout_rate)
baseline_model.summary()
history1 = run_experiment(baseline_model, x_train, y_train)
# Out:
# Model: "baseline"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_features (InputLayer)    [(None, 11)]         0           []
#
#  ffn_block1 (Sequential)        (None, 32)           1612        ['input_features[0][0]']
#
#  ffn_block2 (Sequential)        (None, 32)           2368        ['ffn_block1[0][0]']
#
#  skip_connection2 (Add)         (None, 32)           0           ['ffn_block1[0][0]',
#                                                                   'ffn_block2[0][0]']
#
#  ffn_block3 (Sequential)        (None, 32)           2368        ['skip_connection2[0][0]']
#
#  skip_connection3 (Add)         (None, 32)           0           ['skip_connection2[0][0]',
#                                                                   'ffn_block3[0][0]']
#
#  ffn_block4 (Sequential)        (None, 32)           2368        ['skip_connection3[0][0]']
#
#  skip_connection4 (Add)         (None, 32)           0           ['skip_connection3[0][0]',
#                                                                   'ffn_block4[0][0]']
#
#  ffn_block5 (Sequential)        (None, 32)           2368        ['skip_connection4[0][0]']
#
#  skip_connection5 (Add)         (None, 32)           0           ['skip_connection4[0][0]',
#                                                                   'ffn_block5[0][0]']
#
#  ffn_block6 (Sequential)        (None, 32)           2368        ['skip_connection5[0][0]']
#
#  skip_connection6 (Add)         (None, 32)           0           ['skip_connection5[0][0]',
#                                                                   'ffn_block6[0][0]']
#
#  ffn_block7 (Sequential)        (None, 32)           2368        ['skip_connection6[0][0]']
#
#  skip_connection7 (Add)         (None, 32)           0           ['skip_connection6[0][0]',
#                                                                   'ffn_block7[0][0]']
#
#  ffn_block8 (Sequential)        (None, 32)           2368        ['skip_connection7[0][0]']
#
#  skip_connection8 (Add)         (None, 32)           0           ['skip_connection7[0][0]',
#                                                                   'ffn_block8[0][0]']
#
#  ffn_block9 (Sequential)        (None, 32)           2368        ['skip_connection8[0][0]']
#
#  skip_connection9 (Add)         (None, 32)           0           ['skip_connection8[0][0]',
#                                                                   'ffn_block9[0][0]']
#
#  logits (Dense)                 (None, 7)            231         ['skip_connection9[0][0]']
#
# ==================================================================================================
# Total params: 20,787
# Trainable params: 19,677
# Non-trainable params: 1,110
# __________________________________________________________________________________________________
# Epoch 1/300
# 7/7 [==============================] - 8s 151ms/step - loss: 4.1497 - acc: 0.1895 - val_loss: 2.2821 - val_acc: 0.1355
# Epoch 2/300
# 7/7 [==============================] - 0s 21ms/step - loss: 3.2386 - acc: 0.1648 - val_loss: 2.1120 - val_acc: 0.1355
# Epoch 3/300
# 7/7 [==============================] - 0s 25ms/step - loss: 2.8176 - acc: 0.2025 - val_loss: 2.0547 - val_acc: 0.1209
# Epoch 4/300
# 7/7 [==============================] - 0s 22ms/step - loss: 2.8497 - acc: 0.2154 - val_loss: 1.9823 - val_acc: 0.1099
# Epoch 5/300
# 7/7 [==============================] - 0s 23ms/step - loss: 2.6906 - acc: 0.2096 - val_loss: 2.0254 - val_acc: 0.1062
# Epoch 6/300
# 7/7 [==============================] - 0s 21ms/step - loss: 2.5836 - acc: 0.1694 - val_loss: 2.0122 - val_acc: 0.1575
# Epoch 7/300
# 7/7 [==============================] - 0s 20ms/step - loss: 2.4740 - acc: 0.2116 - val_loss: 1.9958 - val_acc: 0.1575
# Epoch 8/300
# 7/7 [==============================] - 0s 23ms/step - loss: 2.4721 - acc: 0.1739 - val_loss: 2.0040 - val_acc: 0.1612
# Epoch 9/300
# 7/7 [==============================] - 0s 23ms/step - loss: 2.3818 - acc: 0.1791 - val_loss: 1.9226 - val_acc: 0.2308
# Epoch 10/300
# 7/7 [==============================] - 0s 22ms/step - loss: 2.4117 - acc: 0.2667 - val_loss: 1.8900 - val_acc: 0.2821
# Epoch 11/300
# 7/7 [==============================] - 0s 20ms/step - loss: 2.2505 - acc: 0.2265 - val_loss: 1.9055 - val_acc: 0.2747
# Epoch 12/300
# 7/7 [==============================] - 0s 20ms/step - loss: 2.3096 - acc: 0.1836 - val_loss: 1.8974 - val_acc: 0.2821
# Epoch 13/300
# 7/7 [==============================] - 0s 23ms/step - loss: 2.2921 - acc: 0.2583 - val_loss: 1.9062 - val_acc: 0.2821
# Epoch 14/300
# 7/7 [==============================] - 0s 21ms/step - loss: 2.3028 - acc: 0.1966 - val_loss: 1.9330 - val_acc: 0.1355
# Epoch 15/300
# 7/7 [==============================] - 0s 20ms/step - loss: 2.3029 - acc: 0.1843 - val_loss: 1.9428 - val_acc: 0.1392
# Epoch 16/300
# 7/7 [==============================] - 0s 20ms/step - loss: 2.2711 - acc: 0.2641 - val_loss: 1.9345 - val_acc: 0.1795
# Epoch 17/300
# 7/7 [==============================] - 0s 24ms/step - loss: 2.2970 - acc: 0.1992 - val_loss: 1.9176 - val_acc: 0.1868
# Epoch 18/300
# 7/7 [==============================] - 0s 23ms/step - loss: 2.2057 - acc: 0.2025 - val_loss: 1.9252 - val_acc: 0.2821
# Epoch 19/300
# 7/7 [==============================] - 0s 20ms/step - loss: 2.2225 - acc: 0.2485 - val_loss: 1.9033 - val_acc: 0.2747
# Epoch 20/300
# 7/7 [==============================] - 0s 21ms/step - loss: 2.0515 - acc: 0.2511 - val_loss: 1.9004 - val_acc: 0.2784
# Epoch 21/300
# 7/7 [==============================] - 0s 21ms/step - loss: 2.1172 - acc: 0.2537 - val_loss: 1.8950 - val_acc: 0.2821
# Epoch 22/300
# 7/7 [==============================] - 0s 24ms/step - loss: 2.1338 - acc: 0.2466 - val_loss: 1.8850 - val_acc: 0.2821
# Epoch 23/300
# 7/7 [==============================] - 0s 21ms/step - loss: 2.0806 - acc: 0.2226 - val_loss: 1.8940 - val_acc: 0.2821
# Epoch 24/300
# 7/7 [==============================] - 0s 22ms/step - loss: 2.0555 - acc: 0.2797 - val_loss: 1.9131 - val_acc: 0.2491
# Epoch 25/300
# 7/7 [==============================] - 0s 25ms/step - loss: 2.0617 - acc: 0.2349 - val_loss: 1.8990 - val_acc: 0.1832
# Epoch 26/300
# 7/7 [==============================] - 0s 21ms/step - loss: 2.0901 - acc: 0.2693 - val_loss: 1.8841 - val_acc: 0.2821
# Epoch 27/300
# 7/7 [==============================] - 0s 21ms/step - loss: 2.1494 - acc: 0.2239 - val_loss: 1.8767 - val_acc: 0.2784
# Epoch 28/300
# 7/7 [==============================] - 0s 20ms/step - loss: 2.0739 - acc: 0.2446 - val_loss: 1.8777 - val_acc: 0.2821
# Epoch 29/300
# 7/7 [==============================] - 0s 22ms/step - loss: 2.0804 - acc: 0.2797 - val_loss: 1.8710 - val_acc: 0.2784
# Epoch 30/300
# 7/7 [==============================] - 0s 22ms/step - loss: 2.0338 - acc: 0.2356 - val_loss: 1.8917 - val_acc: 0.2747
# Epoch 31/300
# 7/7 [==============================] - 0s 20ms/step - loss: 2.0290 - acc: 0.2070 - val_loss: 1.8879 - val_acc: 0.2821
# Epoch 32/300
# 7/7 [==============================] - 0s 20ms/step - loss: 1.9912 - acc: 0.2648 - val_loss: 1.8913 - val_acc: 0.2821
# Epoch 33/300
# 7/7 [==============================] - 0s 20ms/step - loss: 1.9803 - acc: 0.2589 - val_loss: 1.8920 - val_acc: 0.2821
# Epoch 34/300
# 7/7 [==============================] - 0s 21ms/step - loss: 1.9691 - acc: 0.2816 - val_loss: 1.8939 - val_acc: 0.2821
# Epoch 35/300
# 7/7 [==============================] - 0s 21ms/step - loss: 1.9817 - acc: 0.2667 - val_loss: 1.8812 - val_acc: 0.2821
# Epoch 36/300
# 7/7 [==============================] - 0s 21ms/step - loss: 1.9695 - acc: 0.2524 - val_loss: 1.8799 - val_acc: 0.2821
# Epoch 37/300
# 7/7 [==============================] - 0s 20ms/step - loss: 1.9289 - acc: 0.2576 - val_loss: 1.8881 - val_acc: 0.2821
# Epoch 38/300
# 7/7 [==============================] - 0s 24ms/step - loss: 1.9836 - acc: 0.2492 - val_loss: 1.8971 - val_acc: 0.2784
# Epoch 39/300
# 7/7 [==============================] - 0s 24ms/step - loss: 1.9794 - acc: 0.2771 - val_loss: 1.8773 - val_acc: 0.2821
# Epoch 40/300
# 7/7 [==============================] - 0s 20ms/step - loss: 1.9286 - acc: 0.2816 - val_loss: 1.8726 - val_acc: 0.2784
# Epoch 41/300
# 7/7 [==============================] - 0s 21ms/step - loss: 1.9487 - acc: 0.2745 - val_loss: 1.8817 - val_acc: 0.2821
# Epoch 42/300
# 7/7 [==============================] - 0s 21ms/step - loss: 1.9298 - acc: 0.2946 - val_loss: 1.8822 - val_acc: 0.2784
# Epoch 43/300
# 7/7 [==============================] - 0s 23ms/step - loss: 1.9733 - acc: 0.2492 - val_loss: 1.8911 - val_acc: 0.2784
# Epoch 44/300
# 7/7 [==============================] - 0s 23ms/step - loss: 1.9261 - acc: 0.2700 - val_loss: 1.8838 - val_acc: 0.2821
# Epoch 45/300
# 7/7 [==============================] - 0s 24ms/step - loss: 1.9395 - acc: 0.2459 - val_loss: 1.8784 - val_acc: 0.2784
# Epoch 46/300
# 7/7 [==============================] - 0s 24ms/step - loss: 1.9444 - acc: 0.2531 - val_loss: 1.8826 - val_acc: 0.2784
# Epoch 47/300
# 7/7 [==============================] - 0s 20ms/step - loss: 1.9354 - acc: 0.2907 - val_loss: 1.8868 - val_acc: 0.2821
# Epoch 48/300
# 7/7 [==============================] - 0s 22ms/step - loss: 1.9006 - acc: 0.2771 - val_loss: 1.8935 - val_acc: 0.2711
# Epoch 49/300
# 7/7 [==============================] - 0s 22ms/step - loss: 1.9645 - acc: 0.2362 - val_loss: 1.8777 - val_acc: 0.2747
# Epoch 50/300
# 7/7 [==============================] - 0s 23ms/step - loss: 1.9022 - acc: 0.2842 - val_loss: 1.8723 - val_acc: 0.2821
# Epoch 51/300
# 7/7 [==============================] - 0s 24ms/step - loss: 1.9209 - acc: 0.2920 - val_loss: 1.8612 - val_acc: 0.2821
# Epoch 52/300
# 7/7 [==============================] - 0s 21ms/step - loss: 1.9667 - acc: 0.2537 - val_loss: 1.8828 - val_acc: 0.2784
# Epoch 53/300
# 7/7 [==============================] - 0s 20ms/step - loss: 1.9021 - acc: 0.2641 - val_loss: 1.8886 - val_acc: 0.2821
# Epoch 54/300
# 7/7 [==============================] - 0s 24ms/step - loss: 1.9463 - acc: 0.2713 - val_loss: 1.8951 - val_acc: 0.2784
# Epoch 55/300
# 7/7 [==============================] - 0s 24ms/step - loss: 1.8994 - acc: 0.2862 - val_loss: 1.8767 - val_acc: 0.2821
# Epoch 56/300
# 7/7 [==============================] - 0s 21ms/step - loss: 1.9227 - acc: 0.2881 - val_loss: 1.8824 - val_acc: 0.2784
# Epoch 57/300
# 7/7 [==============================] - 0s 21ms/step - loss: 1.9677 - acc: 0.2687 - val_loss: 1.8850 - val_acc: 0.2711
# Epoch 58/300
# 7/7 [==============================] - 0s 22ms/step - loss: 1.8869 - acc: 0.2855 - val_loss: 1.8771 - val_acc: 0.2747
# Epoch 59/300
# 7/7 [==============================] - 0s 22ms/step - loss: 1.8970 - acc: 0.2868 - val_loss: 1.8690 - val_acc: 0.2821
# Epoch 60/300
# 7/7 [==============================] - 0s 25ms/step - loss: 1.9282 - acc: 0.2894 - val_loss: 1.8658 - val_acc: 0.2821

# %% [markdown]
# Let's plot the learning curves.

# %%
display_learning_curves(history1)

# %% [markdown]
# Now we evaluate the baseline model on the test data split.

# %%
_, test_accuracy = baseline_model.evaluate(x=x_test, y=y_test, verbose=0)
print(f"Test accuracy: {round(test_accuracy * 100, 2)}%")
# Out:
# Test accuracy: 31.66%

# %%
num_features = 1433
baseline_model = create_baseline_model(hidden_units, num_classes, dropout_rate)
baseline_model.summary()
history2 = run_experiment(baseline_model, X_train, Y_train)
# Out:
# Model: "baseline"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_features (InputLayer)    [(None, 1433)]       0           []
#
#  ffn_block1 (Sequential)        (None, 32)           52804       ['input_features[0][0]']
#
#  ffn_block2 (Sequential)        (None, 32)           2368        ['ffn_block1[0][0]']
#
#  skip_connection2 (Add)         (None, 32)           0           ['ffn_block1[0][0]',
#                                                                   'ffn_block2[0][0]']
#
#  ffn_block3 (Sequential)        (None, 32)           2368        ['skip_connection2[0][0]']
#
#  skip_connection3 (Add)         (None, 32)           0           ['skip_connection2[0][0]',
#                                                                   'ffn_block3[0][0]']
#
#  ffn_block4 (Sequential)        (None, 32)           2368        ['skip_connection3[0][0]']
#
#  skip_connection4 (Add)         (None, 32)           0           ['skip_connection3[0][0]',
#                                                                   'ffn_block4[0][0]']
#
#  ffn_block5 (Sequential)        (None, 32)           2368        ['skip_connection4[0][0]']
#
#  skip_connection5 (Add)         (None, 32)           0           ['skip_connection4[0][0]',
#                                                                   'ffn_block5[0][0]']
#
#  ffn_block6 (Sequential)        (None, 32)           2368        ['skip_connection5[0][0]']
#
#  skip_connection6 (Add)         (None, 32)           0           ['skip_connection5[0][0]',
#                                                                   'ffn_block6[0][0]']
#
#  ffn_block7 (Sequential)        (None, 32)           2368        ['skip_connection6[0][0]']
#
#  skip_connection7 (Add)         (None, 32)           0           ['skip_connection6[0][0]',
#                                                                   'ffn_block7[0][0]']
#
#  ffn_block8 (Sequential)        (None, 32)           2368        ['skip_connection7[0][0]']
#
#  skip_connection8 (Add)         (None, 32)           0           ['skip_connection7[0][0]',
#                                                                   'ffn_block8[0][0]']
#
#  ffn_block9 (Sequential)        (None, 32)           2368        ['skip_connection8[0][0]']
#
#  skip_connection9 (Add)         (None, 32)           0           ['skip_connection8[0][0]',
#                                                                   'ffn_block9[0][0]']
#
#  logits (Dense)                 (None, 7)            231         ['skip_connection9[0][0]']
#
# ==================================================================================================
# Total params: 71,979
# Trainable params: 68,025
# Non-trainable params: 3,954
# __________________________________________________________________________________________________
# Epoch 1/300
# 8/8 [==============================] - 9s 163ms/step - loss: 4.4936 - acc: 0.2090 - val_loss: 2.1710 - val_acc: 0.0750
# Epoch 2/300
# 8/8 [==============================] - 0s 39ms/step - loss: 3.2358 - acc: 0.1798 - val_loss: 1.9984 - val_acc: 0.1281
# Epoch 3/300
# 8/8 [==============================] - 0s 36ms/step - loss: 2.7705 - acc: 0.2432 - val_loss: 1.9761 - val_acc: 0.1219
# Epoch 4/300
# 8/8 [==============================] - 0s 34ms/step - loss: 2.4646 - acc: 0.2140 - val_loss: 1.9230 - val_acc: 0.1969
# Epoch 5/300
# 8/8 [==============================] - 0s 35ms/step - loss: 2.2532 - acc: 0.2488 - val_loss: 1.9014 - val_acc: 0.3187
# Epoch 6/300
# 8/8 [==============================] - 0s 35ms/step - loss: 2.1961 - acc: 0.2548 - val_loss: 1.9579 - val_acc: 0.1656
# Epoch 7/300
# 8/8 [==============================] - 0s 34ms/step - loss: 2.0703 - acc: 0.2466 - val_loss: 1.8666 - val_acc: 0.3531
# Epoch 8/300
# 8/8 [==============================] - 0s 34ms/step - loss: 1.9690 - acc: 0.3006 - val_loss: 1.8194 - val_acc: 0.3094
# Epoch 9/300
# 8/8 [==============================] - 0s 32ms/step - loss: 1.9453 - acc: 0.2857 - val_loss: 1.8132 - val_acc: 0.3344
# Epoch 10/300
# 8/8 [==============================] - 0s 33ms/step - loss: 1.8997 - acc: 0.3067 - val_loss: 1.7888 - val_acc: 0.3313
# Epoch 11/300
# 8/8 [==============================] - 0s 37ms/step - loss: 1.8858 - acc: 0.2967 - val_loss: 1.7614 - val_acc: 0.3063
# Epoch 12/300
# 8/8 [==============================] - 0s 35ms/step - loss: 1.7975 - acc: 0.3194 - val_loss: 1.7546 - val_acc: 0.3313
# Epoch 13/300
# 8/8 [==============================] - 0s 34ms/step - loss: 1.7305 - acc: 0.3602 - val_loss: 1.7031 - val_acc: 0.3000
# Epoch 14/300
# 8/8 [==============================] - 0s 35ms/step - loss: 1.7120 - acc: 0.3602 - val_loss: 1.6785 - val_acc: 0.3688
# Epoch 15/300
# 8/8 [==============================] - 0s 37ms/step - loss: 1.6248 - acc: 0.3938 - val_loss: 1.6622 - val_acc: 0.4563
# Epoch 16/300
# 8/8 [==============================] - 0s 37ms/step - loss: 1.5781 - acc: 0.4104 - val_loss: 1.6128 - val_acc: 0.4062
# Epoch 17/300
# 8/8 [==============================] - 0s 37ms/step - loss: 1.5588 - acc: 0.4269 - val_loss: 1.5677 - val_acc: 0.3844
# Epoch 18/300
# 8/8 [==============================] - 0s 34ms/step - loss: 1.5254 - acc: 0.4170 - val_loss: 1.5183 - val_acc: 0.4469
# Epoch 19/300
# 8/8 [==============================] - 0s 34ms/step - loss: 1.4662 - acc: 0.4567 - val_loss: 1.4541 - val_acc: 0.4625
# Epoch 20/300
# 8/8 [==============================] - 0s 37ms/step - loss: 1.4120 - acc: 0.4870 - val_loss: 1.4156 - val_acc: 0.4750
# Epoch 21/300
# 8/8 [==============================] - 0s 34ms/step - loss: 1.3381 - acc: 0.5019 - val_loss: 1.3957 - val_acc: 0.5156
# Epoch 22/300
# 8/8 [==============================] - 0s 34ms/step - loss: 1.3593 - acc: 0.4915 - val_loss: 1.3618 - val_acc: 0.5219
# Epoch 23/300
# 8/8 [==============================] - 0s 35ms/step - loss: 1.2599 - acc: 0.5284 - val_loss: 1.2873 - val_acc: 0.5312
# Epoch 24/300
# 8/8 [==============================] - 0s 37ms/step - loss: 1.2564 - acc: 0.5444 - val_loss: 1.2710 - val_acc: 0.5406
# Epoch 25/300
# 8/8 [==============================] - 0s 35ms/step - loss: 1.2219 - acc: 0.5648 - val_loss: 1.3026 - val_acc: 0.5125
# Epoch 26/300
# 8/8 [==============================] - 0s 37ms/step - loss: 1.1676 - acc: 0.5797 - val_loss: 1.2100 - val_acc: 0.5625
# Epoch 27/300
# 8/8 [==============================] - 0s 39ms/step - loss: 1.1390 - acc: 0.5962 - val_loss: 1.1578 - val_acc: 0.5969
# Epoch 28/300
# 8/8 [==============================] - 0s 33ms/step - loss: 1.0883 - acc: 0.6167 - val_loss: 1.1695 - val_acc: 0.5906
# Epoch 29/300
# 8/8 [==============================] - 0s 31ms/step - loss: 1.0748 - acc: 0.6205 - val_loss: 1.1192 - val_acc: 0.6094
# Epoch 30/300
# 8/8 [==============================] - 0s 33ms/step - loss: 1.0848 - acc: 0.6387 - val_loss: 1.0730 - val_acc: 0.6281
# Epoch 31/300
# 8/8 [==============================] - 0s 35ms/step - loss: 1.0207 - acc: 0.6481 - val_loss: 1.0082 - val_acc: 0.6719
# Epoch 32/300
# 8/8 [==============================] - 0s 32ms/step - loss: 0.9814 - acc: 0.6486 - val_loss: 1.0223 - val_acc: 0.6625
# Epoch 33/300
# 8/8 [==============================] - 0s 31ms/step - loss: 0.9936 - acc: 0.6475 - val_loss: 1.0111 - val_acc: 0.6687
# Epoch 34/300
# 8/8 [==============================] - 0s 35ms/step - loss: 0.9735 - acc: 0.6536 - val_loss: 0.9635 - val_acc: 0.6938
# Epoch 35/300
# 8/8 [==============================] - 0s 34ms/step - loss: 0.9369 - acc: 0.6685 - val_loss: 0.9505 - val_acc: 0.6906
# Epoch 36/300
# 8/8 [==============================] - 0s 34ms/step - loss: 0.9186 - acc: 0.6784 - val_loss: 0.9092 - val_acc: 0.6906
# Epoch 37/300
# 8/8 [==============================] - 0s 31ms/step - loss: 0.9144 - acc: 0.6718 - val_loss: 0.9025 - val_acc: 0.6875
# Epoch 38/300
# 8/8 [==============================] - 0s 34ms/step - loss: 0.8732 - acc: 0.6939 - val_loss: 0.8872 - val_acc: 0.7094
# Epoch 39/300
# 8/8 [==============================] - 0s 37ms/step - loss: 0.8820 - acc: 0.6801 - val_loss: 0.8588 - val_acc: 0.7156
# Epoch 40/300
# 8/8 [==============================] - 0s 31ms/step - loss: 0.8657 - acc: 0.6911 - val_loss: 0.8559 - val_acc: 0.7000
# Epoch 41/300
# 8/8 [==============================] - 0s 33ms/step - loss: 0.8471 - acc: 0.6999 - val_loss: 0.8484 - val_acc: 0.7063
# Epoch 42/300
# 8/8 [==============================] - 0s 33ms/step - loss: 0.8733 - acc: 0.6928 - val_loss: 0.8075 - val_acc: 0.7312
# Epoch 43/300
# 8/8 [==============================] - 0s 33ms/step - loss: 0.8595 - acc: 0.6889 - val_loss: 0.7850 - val_acc: 0.7469
# Epoch 44/300
# 8/8 [==============================] - 0s 33ms/step - loss: 0.8198 - acc: 0.7115 - val_loss: 0.8303 - val_acc: 0.7156
# Epoch 45/300
# 8/8 [==============================] - 0s 31ms/step - loss: 0.8188 - acc: 0.7176 - val_loss: 0.8234 - val_acc: 0.7375
# Epoch 46/300
# 8/8 [==============================] - 0s 33ms/step - loss: 0.8029 - acc: 0.7270 - val_loss: 0.8105 - val_acc: 0.7469
# Epoch 47/300
# 8/8 [==============================] - 0s 35ms/step - loss: 0.8175 - acc: 0.7209 - val_loss: 0.7859 - val_acc: 0.7656
# Epoch 48/300
# 8/8 [==============================] - 0s 33ms/step - loss: 0.7579 - acc: 0.7297 - val_loss: 0.7851 - val_acc: 0.7563
# Epoch 49/300
# 8/8 [==============================] - 0s 33ms/step - loss: 0.7870 - acc: 0.7259 - val_loss: 0.8011 - val_acc: 0.7531
# Epoch 50/300
# 8/8 [==============================] - 0s 38ms/step - loss: 0.8008 - acc: 0.7181 - val_loss: 0.7986 - val_acc: 0.7437
# Epoch 51/300
# 8/8 [==============================] - 0s 32ms/step - loss: 0.7616 - acc: 0.7281 - val_loss: 0.7832 - val_acc: 0.7500
# Epoch 52/300
# 8/8 [==============================] - 0s 32ms/step - loss: 0.7388 - acc: 0.7452 - val_loss: 0.7790 - val_acc: 0.7563
# Epoch 53/300
# 8/8 [==============================] - 0s 36ms/step - loss: 0.7552 - acc: 0.7330 - val_loss: 0.7643 - val_acc: 0.7719
# Epoch 54/300
# 8/8 [==============================] - 0s 34ms/step - loss: 0.7239 - acc: 0.7606 - val_loss: 0.7563 - val_acc: 0.7750
# Epoch 55/300
# 8/8 [==============================] - 0s 32ms/step - loss: 0.7201 - acc: 0.7612 - val_loss: 0.7490 - val_acc: 0.7563
# Epoch 56/300
# 8/8 [==============================] - 0s 32ms/step - loss: 0.7408 - acc: 0.7512 - val_loss: 0.7516 - val_acc: 0.7719
# Epoch 57/300
# 8/8 [==============================] - 0s 34ms/step - loss: 0.7435 - acc: 0.7457 - val_loss: 0.7706 - val_acc: 0.7563
# Epoch 58/300
# 8/8 [==============================] - 0s 32ms/step - loss: 0.7256 - acc: 0.7408 - val_loss: 0.7658 - val_acc: 0.7688
# Epoch 59/300
# 8/8 [==============================] - 0s 31ms/step - loss: 0.7413 - acc: 0.7468 - val_loss: 0.7701 - val_acc: 0.7437
# Epoch 60/300
# 8/8 [==============================] - 0s 32ms/step - loss: 0.7367 - acc: 0.7457 - val_loss: 0.7813 - val_acc: 0.7500
# Epoch 61/300
# 8/8 [==============================] - 0s 35ms/step - loss: 0.7411 - acc: 0.7424 - val_loss: 0.7996 - val_acc: 0.7469
# Epoch 62/300
# 8/8 [==============================] - 0s 34ms/step - loss: 0.6836 - acc: 0.7606 - val_loss: 0.7877 - val_acc: 0.7563
# Epoch 63/300
# 8/8 [==============================] - 0s 33ms/step - loss: 0.7100 - acc: 0.7568 - val_loss: 0.7926 - val_acc: 0.7469
# Epoch 64/300
# 8/8 [==============================] - 0s 32ms/step - loss: 0.6628 - acc: 0.7799 - val_loss: 0.7945 - val_acc: 0.7500
# Epoch 65/300
# 8/8 [==============================] - 0s 34ms/step - loss: 0.7152 - acc: 0.7606 - val_loss: 0.7953 - val_acc: 0.7437
# Epoch 66/300
# 8/8 [==============================] - 0s 33ms/step - loss: 0.6406 - acc: 0.7694 - val_loss: 0.7620 - val_acc: 0.7531
# Epoch 67/300
# 8/8 [==============================] - 0s 35ms/step - loss: 0.6732 - acc: 0.7595 - val_loss: 0.7801 - val_acc: 0.7437
# Epoch 68/300
# 8/8 [==============================] - 0s 32ms/step - loss: 0.6569 - acc: 0.7832 - val_loss: 0.7955 - val_acc: 0.7437
# Epoch 69/300
# 8/8 [==============================] - 0s 33ms/step - loss: 0.6771 - acc: 0.7672 - val_loss: 0.8056 - val_acc: 0.7469
# Epoch 70/300
# 8/8 [==============================] - 0s 33ms/step - loss: 0.6366 - acc: 0.7761 - val_loss: 0.8032 - val_acc: 0.7437
# Epoch 71/300
# 8/8 [==============================] - 0s 32ms/step - loss: 0.6718 - acc: 0.7755 - val_loss: 0.7995 - val_acc: 0.7500
# Epoch 72/300
# 8/8 [==============================] - 0s 34ms/step - loss: 0.6371 - acc: 0.7854 - val_loss: 0.8315 - val_acc: 0.7437
# Epoch 73/300
# 8/8 [==============================] - 0s 34ms/step - loss: 0.6368 - acc: 0.7716 - val_loss: 0.8440 - val_acc: 0.7375
# Epoch 74/300
# 8/8 [==============================] - 0s 32ms/step - loss: 0.6277 - acc: 0.7827 - val_loss: 0.8238 - val_acc: 0.7406
# Epoch 75/300
# 8/8 [==============================] - 0s 32ms/step - loss: 0.6355 - acc: 0.7799 - val_loss: 0.8177 - val_acc: 0.7406
# Epoch 76/300
# 8/8 [==============================] - 0s 31ms/step - loss: 0.6360 - acc: 0.7865 - val_loss: 0.8321 - val_acc: 0.7469
# Epoch 77/300
# 8/8 [==============================] - 0s 31ms/step - loss: 0.6248 - acc: 0.7965 - val_loss: 0.8336 - val_acc: 0.7406
# Epoch 78/300
# 8/8 [==============================] - 0s 34ms/step - loss: 0.6566 - acc: 0.7739 - val_loss: 0.8353 - val_acc: 0.7375
# Epoch 79/300
# 8/8 [==============================] - 0s 32ms/step - loss: 0.6103 - acc: 0.7827 - val_loss: 0.8664 - val_acc: 0.7406
# Epoch 80/300
# 8/8 [==============================] - 0s 35ms/step - loss: 0.6304 - acc: 0.7772 - val_loss: 0.8876 - val_acc: 0.7375
# Epoch 81/300
# 8/8 [==============================] - 0s 34ms/step - loss: 0.6108 - acc: 0.7876 - val_loss: 0.8734 - val_acc: 0.7344
# Epoch 82/300
# 8/8 [==============================] - 0s 32ms/step - loss: 0.6297 - acc: 0.7744 - val_loss: 0.8600 - val_acc: 0.7312
# Epoch 83/300
# 8/8 [==============================] - 0s 32ms/step - loss: 0.6151 - acc: 0.7915 - val_loss: 0.8526 - val_acc: 0.7281
# Epoch 84/300
# 8/8 [==============================] - 0s 33ms/step - loss: 0.6140 - acc: 0.7799 - val_loss: 0.8601 - val_acc: 0.7344
# Epoch 85/300
# 8/8 [==============================] - 0s 34ms/step - loss: 0.5886 - acc: 0.7899 - val_loss: 0.9027 - val_acc: 0.7219
# Epoch 86/300
# 8/8 [==============================] - 0s 34ms/step - loss: 0.5910 - acc: 0.7992 - val_loss: 0.9013 - val_acc: 0.7281
# Epoch 87/300
# 8/8 [==============================] - 0s 35ms/step - loss: 0.5754 - acc: 0.8042 - val_loss: 0.8869 - val_acc: 0.7375
# Epoch 88/300
# 8/8 [==============================] - 0s 36ms/step - loss: 0.6004 - acc: 0.7843 - val_loss: 0.8861 - val_acc: 0.7281
# Epoch 89/300
# 8/8 [==============================] - 0s 31ms/step - loss: 0.5882 - acc: 0.7860 - val_loss: 0.8918 - val_acc: 0.7250
# Epoch 90/300
# 8/8 [==============================] - 0s 32ms/step - loss: 0.5919 - acc: 0.7904 - val_loss: 0.8939 - val_acc: 0.7312
# Epoch 91/300
# 8/8 [==============================] - 0s 33ms/step - loss: 0.6148 - acc: 0.7816 - val_loss: 0.8956 - val_acc: 0.7375
# Epoch 92/300
# 8/8 [==============================] - 0s 34ms/step - loss: 0.6091 - acc: 0.7904 - val_loss: 0.8870 - val_acc: 0.7250
# Epoch 93/300
# 8/8 [==============================] - 0s 31ms/step - loss: 0.5950 - acc: 0.7899 - val_loss: 0.8913 - val_acc: 0.7219
# Epoch 94/300
# 8/8 [==============================] - 0s 34ms/step - loss: 0.6021 - acc: 0.7733 - val_loss: 0.9136 - val_acc: 0.7094
# Epoch 95/300
# 8/8 [==============================] - 0s 35ms/step - loss: 0.6096 - acc: 0.7948 - val_loss: 0.9203 - val_acc: 0.7250
# Epoch 96/300
# 8/8 [==============================] - 0s 32ms/step - loss: 0.5995 - acc: 0.7766 - val_loss: 0.9274 - val_acc: 0.7250
# Epoch 97/300
# 8/8 [==============================] - 0s 35ms/step - loss: 0.6262 - acc: 0.7799 - val_loss: 0.9157 - val_acc: 0.7281
# Epoch 98/300
# 8/8 [==============================] - 0s 36ms/step - loss: 0.5940 - acc: 0.7926 - val_loss: 0.9155 - val_acc: 0.7344
# Epoch 99/300
# 8/8 [==============================] - 0s 35ms/step - loss: 0.5717 - acc: 0.7932 - val_loss: 0.9351 - val_acc: 0.7312
# Epoch 100/300
# 8/8 [==============================] - 0s 33ms/step - loss: 0.5635 - acc: 0.8097 - val_loss: 0.9453 - val_acc: 0.7312
# Epoch 101/300
# 8/8 [==============================] - 0s 36ms/step - loss: 0.5794 - acc: 0.7981 - val_loss: 0.9368 - val_acc: 0.7344
# Epoch 102/300
# 8/8 [==============================] - 0s 33ms/step - loss: 0.5716 - acc: 0.8053 - val_loss: 0.9592 - val_acc: 0.7312
# Epoch 103/300
# 8/8 [==============================] - 0s 35ms/step - loss: 0.5557 - acc: 0.8114 - val_loss: 0.9484 - val_acc: 0.7344
# Epoch 104/300
# 8/8 [==============================] - 0s 36ms/step - loss: 0.5853 - acc: 0.7871 - val_loss: 0.9396 - val_acc: 0.7406

# %%
display_learning_curves(history2)

# %%
_, test_accuracy = baseline_model.evaluate(x=X_test, y=Y_test, verbose=0)
print(f"Test accuracy: {round(test_accuracy * 100, 2)}%")
# Out:
# Test accuracy: 76.87%

# %% [markdown]
# ## Build a Graph Neural Network Model
#
# ### Prepare the data for the graph model
#
# Preparing and loading the graphs data into the model for training is the most challenging
# part in GNN models, which is addressed in different ways by the specialised libraries.
# In this example, we show a simple approach for preparing and using graph data that is suitable
# if your dataset consists of a single graph that fits entirely in memory.
#
# The graph data is represented by the `graph_info` tuple, which consists of the following
# three elements:
#
# 1. `node_features`: This is a `[num_nodes, num_features]` NumPy array that includes the
# node features. In this dataset, the nodes are the papers, and the `node_features` are the
# word-presence binary vectors of each paper.
# 2. `edges`:  This is `[num_edges, num_edges]` NumPy array representing a sparse
# [adjacency matrix](https://en.wikipedia.org/wiki/Adjacency_matrix#:~:text=In%20graph%20theory%20and%20computer,with%20zeros%20on%20its%20diagonal.)
# of the links between the nodes. In this example, the links are the citations between the papers.
# 3. `edge_weights` (optional): This is a `[num_edges]` NumPy array that includes the edge weights, which *quantify*
# the relationships between nodes in the graph. In this example, there are no weights for the paper citations.

# %%
# Create an edges array (sparse adjacency matrix) of shape [2, num_edges].
edges = citations[["source", "target"]].to_numpy().T
# Create an edge weights array of ones.
edge_weights = tf.ones(shape=edges.shape[1])
# Create a node features array of shape [num_nodes, num_features].
node_features = tf.cast(
    papers.sort_values("paper_id")[feature_names].to_numpy(), dtype=tf.dtypes.float32
)
# Create graph info tuple with node_features, edges, and edge_weights.
graph_info = (node_features, edges, edge_weights)

print("Edges shape:", edges.shape)
print("Nodes shape:", node_features.shape)
# Out:
# Edges shape: (2, 5429)
# Nodes shape: (2708, 1433)

# %% [markdown]
# ### Implement a graph convolution layer
#
# We implement a graph convolution module as a [Keras Layer](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Layer?version=nightly).
# Our `GraphConvLayer` performs the following steps:
#
# 1. **Prepare**: The input node representations are processed using a FFN to produce a *message*. You can simplify
# the processing by only applying linear transformation to the representations.
# 2. **Aggregate**: The messages of the neighbours of each node are aggregated with
# respect to the `edge_weights` using a *permutation invariant* pooling operation, such as *sum*, *mean*, and *max*,
# to prepare a single aggregated message for each node. See, for example, [tf.math.unsorted_segment_sum](https://www.tensorflow.org/api_docs/python/tf/math/unsorted_segment_sum)
# APIs used to aggregate neighbour messages.
# 3. **Update**: The `node_repesentations` and `aggregated_messages`—both of shape `[num_nodes, representation_dim]`—
# are combined and processed to produce the new state of the node representations (node embeddings).
# If `combination_type` is `gru`, the `node_repesentations` and `aggregated_messages` are stacked to create a sequence,
# then processed by a GRU layer. Otherwise, the `node_repesentations` and `aggregated_messages` are added
# or concatenated, then processed using a FFN.
#
#
# The technique implemented use ideas from [Graph Convolutional Networks](https://arxiv.org/abs/1609.02907),
# [GraphSage](https://arxiv.org/abs/1706.02216), [Graph Isomorphism Network](https://arxiv.org/abs/1810.00826),
# [Simple Graph Networks](https://arxiv.org/abs/1902.07153), and
# [Gated Graph Sequence Neural Networks](https://arxiv.org/abs/1511.05493).
# Two other key techniques that are not covered are [Graph Attention Networks](https://arxiv.org/abs/1710.10903)
# and [Message Passing Neural Networks](https://arxiv.org/abs/1704.01212).

# %%
class GraphConvLayer(layers.Layer):
    def __init__(
        self,
        hidden_units,
        dropout_rate=0.2,
        aggregation_type="mean",
        combination_type="concat",
        normalize=False,
        *args,
        **kwargs,
    ):
        super(GraphConvLayer, self).__init__(*args, **kwargs)

        self.aggregation_type = aggregation_type
        self.combination_type = combination_type
        self.normalize = normalize

        self.ffn_prepare = create_ffn(hidden_units, dropout_rate)
        if self.combination_type == "gated":
            self.update_fn = layers.GRU(
                units=hidden_units,
                activation="tanh",
                recurrent_activation="sigmoid",
                dropout=dropout_rate,
                return_state=True,
                recurrent_dropout=dropout_rate,
            )
        else:
            self.update_fn = create_ffn(hidden_units, dropout_rate)

    def prepare(self, node_repesentations, weights=None):
        # node_repesentations shape is [num_edges, embedding_dim].
        messages = self.ffn_prepare(node_repesentations)
        if weights is not None:
            messages = messages * tf.expand_dims(weights, -1)
        return messages

    def aggregate(self, node_indices, neighbour_messages):
        # node_indices shape is [num_edges].
        # neighbour_messages shape: [num_edges, representation_dim].
        num_nodes = tf.math.reduce_max(node_indices) + 1
        if self.aggregation_type == "sum":
            aggregated_message = tf.math.unsorted_segment_sum(
                neighbour_messages, node_indices, num_segments=num_nodes
            )
        elif self.aggregation_type == "mean":
            aggregated_message = tf.math.unsorted_segment_mean(
                neighbour_messages, node_indices, num_segments=num_nodes
            )
        elif self.aggregation_type == "max":
            aggregated_message = tf.math.unsorted_segment_max(
                neighbour_messages, node_indices, num_segments=num_nodes
            )
        else:
            raise ValueError(f"Invalid aggregation type: {self.aggregation_type}.")

        return aggregated_message

    def update(self, node_repesentations, aggregated_messages):
        # node_repesentations shape is [num_nodes, representation_dim].
        # aggregated_messages shape is [num_nodes, representation_dim].
        if self.combination_type == "gru":
            # Create a sequence of two elements for the GRU layer.
            h = tf.stack([node_repesentations, aggregated_messages], axis=1)
        elif self.combination_type == "concat":
            # Concatenate the node_repesentations and aggregated_messages.
            h = tf.concat([node_repesentations, aggregated_messages], axis=1)
        elif self.combination_type == "add":
            # Add node_repesentations and aggregated_messages.
            h = node_repesentations + aggregated_messages
        else:
            raise ValueError(f"Invalid combination type: {self.combination_type}.")

        # Apply the processing function.
        node_embeddings = self.update_fn(h)
        if self.combination_type == "gru":
            node_embeddings = tf.unstack(node_embeddings, axis=1)[-1]

        if self.normalize:
            node_embeddings = tf.nn.l2_normalize(node_embeddings, axis=-1)
        return node_embeddings

    def call(self, inputs):
        """Process the inputs to produce the node_embeddings.

        inputs: a tuple of three elements: node_repesentations, edges, edge_weights.
        Returns: node_embeddings of shape [num_nodes, representation_dim].
        """

        node_repesentations, edges, edge_weights = inputs
        # Get node_indices (source) and neighbour_indices (target) from edges.
        node_indices, neighbour_indices = edges[0], edges[1]
        # neighbour_repesentations shape is [num_edges, representation_dim].
        neighbour_repesentations = tf.gather(node_repesentations, neighbour_indices)

        # Prepare the messages of the neighbours.
        neighbour_messages = self.prepare(neighbour_repesentations, edge_weights)
        # Aggregate the neighbour messages.
        aggregated_messages = self.aggregate(node_indices, neighbour_messages)
        # Update the node embedding with the neighbour messages.
        return self.update(node_repesentations, aggregated_messages)

# %% [markdown]
# ### Implement a graph neural network node classifier
#
# The GNN classification model follows the [Design Space for Graph Neural Networks](https://arxiv.org/abs/2011.08843) approach,
# as follows:
#
# 1. Apply preprocessing using FFN to the node features to generate initial node representations.
# 2. Apply one or more graph convolutional layer, with skip connections,  to the node representation
# to produce node embeddings.
# 3. Apply post-processing using FFN to the node embeddings to generat the final node embeddings.
# 4. Feed the node embeddings in a Softmax layer to predict the node class.
#
# Each graph convolutional layer added captures information from a further level of neighbours.
# However, adding many graph convolutional layer can cause oversmoothing, where the model
# produces similar embeddings for all the nodes.
#
# Note that the `graph_info` passed to the constructor of the Keras model, and used as a *property*
# of the Keras model object, rather than input data for training or prediction.
# The model will accept a **batch** of `node_indices`, which are used to lookup the
# node features and neighbours from the `graph_info`.

# %%
class GNNNodeClassifier(tf.keras.Model):
    def __init__(
        self,
        graph_info,
        num_classes,
        hidden_units,
        aggregation_type="sum",
        combination_type="concat",
        dropout_rate=0.2,
        normalize=True,
        *args,
        **kwargs,
    ):
        super(GNNNodeClassifier, self).__init__(*args, **kwargs)

        # Unpack graph_info to three elements: node_features, edges, and edge_weight.
        node_features, edges, edge_weights = graph_info
        self.node_features = node_features
        self.edges = edges
        self.edge_weights = edge_weights
        # Set edge_weights to ones if not provided.
        if self.edge_weights is None:
            self.edge_weights = tf.ones(shape=edges.shape[1])
        # Scale edge_weights to sum to 1.
        self.edge_weights = self.edge_weights / tf.math.reduce_sum(self.edge_weights)

        # Create a process layer.
        self.preprocess = create_ffn(hidden_units, dropout_rate, name="preprocess")
        # Create the first GraphConv layer.
        self.conv1 = GraphConvLayer(
            hidden_units,
            dropout_rate,
            aggregation_type,
            combination_type,
            normalize,
            name="graph_conv1",
        )
        # Create the second GraphConv layer.
        self.conv2 = GraphConvLayer(
            hidden_units,
            dropout_rate,
            aggregation_type,
            combination_type,
            normalize,
            name="graph_conv2",
        )
        # Create the third GraphConv layer.
        self.conv3 = GraphConvLayer(
            hidden_units,
            dropout_rate,
            aggregation_type,
            combination_type,
            normalize,
            name="graph_conv3",
        )
        # Create the forth GraphConv layer.
        self.conv4 = GraphConvLayer(
            hidden_units,
            dropout_rate,
            aggregation_type,
            combination_type,
            normalize,
            name="graph_conv4",
        )
        # Create the fifth GraphConv layer.
        self.conv5 = GraphConvLayer(
            hidden_units,
            dropout_rate,
            aggregation_type,
            combination_type,
            normalize,
            name="graph_conv5",
        )
        # Create the sixth GraphConv layer.
        self.conv6 = GraphConvLayer(
            hidden_units,
            dropout_rate,
            aggregation_type,
            combination_type,
            normalize,
            name="graph_conv6",
        )
        # Create a postprocess layer.
        self.postprocess = create_ffn(hidden_units, dropout_rate, name="postprocess")
        # Create a compute logits layer.
        self.compute_logits = layers.Dense(units=num_classes, name="logits")

    def call(self, input_node_indices):
        # Preprocess the node_features to produce node representations.
        x = self.preprocess(self.node_features)
        # Apply the first graph conv layer.
        x1 = self.conv1((x, self.edges, self.edge_weights))
        # Skip connection.
        x = x1 + x
        # Apply the second graph conv layer.
        x2 = self.conv2((x, self.edges, self.edge_weights))
        # Skip connection.
        x = x2 + x
        # Apply the third graph conv layer.
        x3 = self.conv3((x, self.edges, self.edge_weights))
        # Skip connection.
        x = x3 + x
        # Apply the forth graph conv layer.
        x4 = self.conv4((x, self.edges, self.edge_weights))
        # Skip connection.
        x = x4 + x
        # Apply the fifth graph conv layer.
        x5 = self.conv5((x, self.edges, self.edge_weights))
        # Skip connection.
        x = x5 + x
        # Apply the sixth graph conv layer.
        x6 = self.conv6((x, self.edges, self.edge_weights))
        # Skip connection.
        x = x6 + x
        # Postprocess node embedding.
        x = self.postprocess(x)
        # Fetch node embeddings for the input node_indices.
        node_embeddings = tf.gather(x, input_node_indices)
        # Compute logits
        return self.compute_logits(node_embeddings)

# %% [markdown]
# Let's test instantiating and calling the GNN model.
# Notice that if you provide `N` node indices, the output will be a tensor of shape `[N, num_classes]`,
# regardless of the size of the graph.

# %%
gnn_model = GNNNodeClassifier(
    graph_info=graph_info,
    num_classes=num_classes,
    hidden_units=hidden_units,
    dropout_rate=dropout_rate,
    name="gnn_model",
)

print("GNN output shape:", gnn_model([1, 10, 100]))

gnn_model.summary()
# Out:
# GNN output shape: tf.Tensor(
# [[ 0.09034015  0.16198921  0.08819403 -0.04069054  0.17935938 -0.10718262
#    0.07998101]
#  [ 0.10768702 -0.16038696  0.04465969 -0.06190166  0.00925937  0.24224836
#    0.25852168]
#  [-0.33271918  0.14178383  0.1915713  -0.11160773 -0.14455222  0.44772953
#    0.29957685]], shape=(3, 7), dtype=float32)
# Model: "gnn_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  preprocess (Sequential)     (2708, 32)                52804
#
#  graph_conv1 (GraphConvLayer  multiple                 5888
#  )
#
#  graph_conv2 (GraphConvLayer  multiple                 5888
#  )
#
#  graph_conv3 (GraphConvLayer  multiple                 5888
#  )
#
#  graph_conv4 (GraphConvLayer  multiple                 5888
#  )
#
#  graph_conv5 (GraphConvLayer  multiple                 5888
#  )
#
#  graph_conv6 (GraphConvLayer  multiple                 5888
#  )
#
#  postprocess (Sequential)    (2708, 32)                2368
#
#  logits (Dense)              multiple                  231
#
# =================================================================
# Total params: 90,731
# Trainable params: 85,753
# Non-trainable params: 4,978
# _________________________________________________________________

# %% [markdown]
# ### Train the GNN model
#
# Note that we use the standard *supervised* cross-entropy loss to train the model.
# However, we can add another *self-supervised* loss term for the generated node embeddings
# that makes sure that neighbouring nodes in graph have similar representations, while faraway
# nodes have dissimilar representations.

# %%
X_train = train_data.paper_id.to_numpy()
history = run_experiment(gnn_model, X_train, Y_train)
# Out:
# Epoch 1/300
# 8/8 [==============================] - 14s 512ms/step - loss: 2.1631 - acc: 0.1958 - val_loss: 1.8884 - val_acc: 0.2438
# Epoch 2/300
# 8/8 [==============================] - 3s 316ms/step - loss: 1.9456 - acc: 0.2598 - val_loss: 1.8922 - val_acc: 0.2969
# Epoch 3/300
# 8/8 [==============================] - 3s 323ms/step - loss: 1.8914 - acc: 0.2769 - val_loss: 1.8900 - val_acc: 0.2906
# Epoch 4/300
# 8/8 [==============================] - 3s 314ms/step - loss: 1.8537 - acc: 0.2774 - val_loss: 1.8835 - val_acc: 0.3000
# Epoch 5/300
# 8/8 [==============================] - 2s 311ms/step - loss: 1.8402 - acc: 0.2962 - val_loss: 1.8702 - val_acc: 0.3000
# Epoch 6/300
# 8/8 [==============================] - 2s 311ms/step - loss: 1.8325 - acc: 0.3045 - val_loss: 1.8649 - val_acc: 0.3000
# Epoch 7/300
# 8/8 [==============================] - 3s 317ms/step - loss: 1.8265 - acc: 0.2990 - val_loss: 1.8654 - val_acc: 0.2844
# Epoch 8/300
# 8/8 [==============================] - 3s 315ms/step - loss: 1.8205 - acc: 0.2978 - val_loss: 1.8560 - val_acc: 0.3063
# Epoch 9/300
# 8/8 [==============================] - 3s 331ms/step - loss: 1.8114 - acc: 0.3039 - val_loss: 1.8487 - val_acc: 0.3000
# Epoch 10/300
# 8/8 [==============================] - 3s 316ms/step - loss: 1.7939 - acc: 0.3034 - val_loss: 1.8357 - val_acc: 0.3000
# Epoch 11/300
# 8/8 [==============================] - 3s 322ms/step - loss: 1.7909 - acc: 0.2984 - val_loss: 1.8286 - val_acc: 0.3250
# Epoch 12/300
# 8/8 [==============================] - 3s 317ms/step - loss: 1.7650 - acc: 0.3039 - val_loss: 1.8033 - val_acc: 0.2812
# Epoch 13/300
# 8/8 [==============================] - 3s 323ms/step - loss: 1.7522 - acc: 0.3056 - val_loss: 1.7881 - val_acc: 0.2094
# Epoch 14/300
# 8/8 [==============================] - 3s 325ms/step - loss: 1.7269 - acc: 0.3183 - val_loss: 1.7568 - val_acc: 0.2812
# Epoch 15/300
# 8/8 [==============================] - 3s 330ms/step - loss: 1.6821 - acc: 0.3293 - val_loss: 1.7158 - val_acc: 0.2969
# Epoch 16/300
# 8/8 [==============================] - 3s 317ms/step - loss: 1.6533 - acc: 0.3354 - val_loss: 1.7832 - val_acc: 0.3219
# Epoch 17/300
# 8/8 [==============================] - 3s 317ms/step - loss: 1.5766 - acc: 0.3784 - val_loss: 1.7901 - val_acc: 0.3781
# Epoch 18/300
# 8/8 [==============================] - 3s 318ms/step - loss: 1.5763 - acc: 0.3734 - val_loss: 1.9037 - val_acc: 0.3438
# Epoch 19/300
# 8/8 [==============================] - 3s 317ms/step - loss: 1.5202 - acc: 0.4104 - val_loss: 1.9692 - val_acc: 0.3969
# Epoch 20/300
# 8/8 [==============================] - 3s 322ms/step - loss: 1.4774 - acc: 0.4242 - val_loss: 1.8482 - val_acc: 0.4313
# Epoch 21/300
# 8/8 [==============================] - 3s 326ms/step - loss: 1.4003 - acc: 0.4567 - val_loss: 1.7757 - val_acc: 0.4500
# Epoch 22/300
# 8/8 [==============================] - 2s 313ms/step - loss: 1.3955 - acc: 0.4749 - val_loss: 1.9848 - val_acc: 0.4938
# Epoch 23/300
# 8/8 [==============================] - 2s 312ms/step - loss: 1.3006 - acc: 0.5119 - val_loss: 2.3903 - val_acc: 0.4344
# Epoch 24/300
# 8/8 [==============================] - 2s 315ms/step - loss: 1.2590 - acc: 0.5339 - val_loss: 2.3595 - val_acc: 0.4344
# Epoch 25/300
# 8/8 [==============================] - 3s 327ms/step - loss: 1.2284 - acc: 0.5433 - val_loss: 2.0445 - val_acc: 0.4844
# Epoch 26/300
# 8/8 [==============================] - 3s 350ms/step - loss: 1.2045 - acc: 0.5527 - val_loss: 2.2400 - val_acc: 0.4719
# Epoch 27/300
# 8/8 [==============================] - 3s 348ms/step - loss: 1.1592 - acc: 0.5643 - val_loss: 1.9156 - val_acc: 0.5156
# Epoch 28/300
# 8/8 [==============================] - 3s 333ms/step - loss: 1.1060 - acc: 0.5858 - val_loss: 1.8548 - val_acc: 0.5250
# Epoch 29/300
# 8/8 [==============================] - 3s 330ms/step - loss: 1.0981 - acc: 0.6018 - val_loss: 1.4532 - val_acc: 0.5688
# Epoch 30/300
# 8/8 [==============================] - 3s 324ms/step - loss: 1.0678 - acc: 0.6056 - val_loss: 1.2874 - val_acc: 0.5688
# Epoch 31/300
# 8/8 [==============================] - 3s 338ms/step - loss: 1.0661 - acc: 0.6034 - val_loss: 1.0056 - val_acc: 0.6313
# Epoch 32/300
# 8/8 [==============================] - 3s 330ms/step - loss: 1.0019 - acc: 0.6288 - val_loss: 0.9077 - val_acc: 0.6469
# Epoch 33/300
# 8/8 [==============================] - 3s 336ms/step - loss: 0.9526 - acc: 0.6492 - val_loss: 0.9315 - val_acc: 0.6406
# Epoch 34/300
# 8/8 [==============================] - 3s 324ms/step - loss: 0.9589 - acc: 0.6470 - val_loss: 0.9350 - val_acc: 0.6562
# Epoch 35/300
# 8/8 [==============================] - 3s 317ms/step - loss: 0.9814 - acc: 0.6354 - val_loss: 1.0766 - val_acc: 0.6250
# Epoch 36/300
# 8/8 [==============================] - 3s 318ms/step - loss: 0.9208 - acc: 0.6619 - val_loss: 1.1407 - val_acc: 0.6219
# Epoch 37/300
# 8/8 [==============================] - 3s 327ms/step - loss: 0.9387 - acc: 0.6475 - val_loss: 0.9599 - val_acc: 0.6594
# Epoch 38/300
# 8/8 [==============================] - 3s 338ms/step - loss: 0.9330 - acc: 0.6536 - val_loss: 0.9351 - val_acc: 0.6687
# Epoch 39/300
# 8/8 [==============================] - 3s 318ms/step - loss: 0.9159 - acc: 0.6795 - val_loss: 0.9272 - val_acc: 0.6500
# Epoch 40/300
# 8/8 [==============================] - 2s 312ms/step - loss: 0.8647 - acc: 0.6751 - val_loss: 0.9143 - val_acc: 0.6438
# Epoch 41/300
# 8/8 [==============================] - 3s 320ms/step - loss: 0.8539 - acc: 0.7022 - val_loss: 0.8523 - val_acc: 0.6812
# Epoch 42/300
# 8/8 [==============================] - 2s 311ms/step - loss: 0.8472 - acc: 0.7088 - val_loss: 0.8592 - val_acc: 0.6750
# Epoch 43/300
# 8/8 [==============================] - 3s 319ms/step - loss: 0.8342 - acc: 0.6906 - val_loss: 1.0012 - val_acc: 0.6281
# Epoch 44/300
# 8/8 [==============================] - 2s 311ms/step - loss: 0.8446 - acc: 0.6873 - val_loss: 1.0841 - val_acc: 0.6125
# Epoch 45/300
# 8/8 [==============================] - 2s 307ms/step - loss: 0.8316 - acc: 0.7088 - val_loss: 1.2019 - val_acc: 0.5875
# Epoch 46/300
# 8/8 [==============================] - 2s 308ms/step - loss: 0.8311 - acc: 0.7110 - val_loss: 1.1035 - val_acc: 0.6500
# Epoch 47/300
# 8/8 [==============================] - 2s 310ms/step - loss: 0.8166 - acc: 0.7115 - val_loss: 0.8134 - val_acc: 0.7250
# Epoch 48/300
# 8/8 [==============================] - 2s 307ms/step - loss: 0.8233 - acc: 0.7005 - val_loss: 0.8615 - val_acc: 0.6906
# Epoch 49/300
# 8/8 [==============================] - 2s 309ms/step - loss: 0.7920 - acc: 0.7115 - val_loss: 0.9125 - val_acc: 0.7219
# Epoch 50/300
# 8/8 [==============================] - 3s 329ms/step - loss: 0.8030 - acc: 0.7209 - val_loss: 0.8313 - val_acc: 0.7344
# Epoch 51/300
# 8/8 [==============================] - 2s 305ms/step - loss: 0.7988 - acc: 0.7093 - val_loss: 0.9237 - val_acc: 0.7031
# Epoch 52/300
# 8/8 [==============================] - 3s 316ms/step - loss: 0.8042 - acc: 0.7115 - val_loss: 0.9615 - val_acc: 0.6812
# Epoch 53/300
# 8/8 [==============================] - 2s 313ms/step - loss: 0.7898 - acc: 0.7220 - val_loss: 0.9030 - val_acc: 0.6938
# Epoch 54/300
# 8/8 [==============================] - 2s 311ms/step - loss: 0.7811 - acc: 0.7275 - val_loss: 0.8642 - val_acc: 0.6906
# Epoch 55/300
# 8/8 [==============================] - 2s 307ms/step - loss: 0.7299 - acc: 0.7435 - val_loss: 0.8704 - val_acc: 0.6969
# Epoch 56/300
# 8/8 [==============================] - 3s 319ms/step - loss: 0.7589 - acc: 0.7534 - val_loss: 0.7341 - val_acc: 0.7531
# Epoch 57/300
# 8/8 [==============================] - 2s 309ms/step - loss: 0.7172 - acc: 0.7380 - val_loss: 0.6677 - val_acc: 0.7781
# Epoch 58/300
# 8/8 [==============================] - 2s 305ms/step - loss: 0.7383 - acc: 0.7363 - val_loss: 0.7064 - val_acc: 0.7656
# Epoch 59/300
# 8/8 [==============================] - 2s 302ms/step - loss: 0.6818 - acc: 0.7667 - val_loss: 0.7747 - val_acc: 0.7688
# Epoch 60/300
# 8/8 [==============================] - 2s 306ms/step - loss: 0.6406 - acc: 0.7755 - val_loss: 0.7112 - val_acc: 0.7688
# Epoch 61/300
# 8/8 [==============================] - 2s 306ms/step - loss: 0.7269 - acc: 0.7501 - val_loss: 0.6972 - val_acc: 0.7500
# Epoch 62/300
# 8/8 [==============================] - 2s 309ms/step - loss: 0.7093 - acc: 0.7562 - val_loss: 0.6680 - val_acc: 0.7750
# Epoch 63/300
# 8/8 [==============================] - 2s 306ms/step - loss: 0.6901 - acc: 0.7728 - val_loss: 0.6241 - val_acc: 0.8000
# Epoch 64/300
# 8/8 [==============================] - 2s 300ms/step - loss: 0.6998 - acc: 0.7722 - val_loss: 0.7317 - val_acc: 0.7469
# Epoch 65/300
# 8/8 [==============================] - 2s 310ms/step - loss: 0.6973 - acc: 0.7590 - val_loss: 0.6972 - val_acc: 0.7688
# Epoch 66/300
# 8/8 [==============================] - 3s 317ms/step - loss: 0.6713 - acc: 0.7728 - val_loss: 0.7238 - val_acc: 0.7563
# Epoch 67/300
# 8/8 [==============================] - 3s 316ms/step - loss: 0.6955 - acc: 0.7595 - val_loss: 0.6960 - val_acc: 0.7500
# Epoch 68/300
# 8/8 [==============================] - 2s 313ms/step - loss: 0.6918 - acc: 0.7601 - val_loss: 0.6181 - val_acc: 0.8031
# Epoch 69/300
# 8/8 [==============================] - 2s 311ms/step - loss: 0.6566 - acc: 0.7899 - val_loss: 0.7023 - val_acc: 0.7781
# Epoch 70/300
# 8/8 [==============================] - 2s 313ms/step - loss: 0.6764 - acc: 0.7705 - val_loss: 0.6129 - val_acc: 0.8094
# Epoch 71/300
# 8/8 [==============================] - 2s 306ms/step - loss: 0.6774 - acc: 0.7711 - val_loss: 0.5682 - val_acc: 0.8281
# Epoch 72/300
# 8/8 [==============================] - 2s 307ms/step - loss: 0.6576 - acc: 0.7788 - val_loss: 0.5600 - val_acc: 0.8156
# Epoch 73/300
# 8/8 [==============================] - 2s 308ms/step - loss: 0.6463 - acc: 0.7821 - val_loss: 0.5810 - val_acc: 0.8188
# Epoch 74/300
# 8/8 [==============================] - 2s 315ms/step - loss: 0.6589 - acc: 0.7816 - val_loss: 0.6160 - val_acc: 0.7937
# Epoch 75/300
# 8/8 [==============================] - 2s 304ms/step - loss: 0.6274 - acc: 0.7821 - val_loss: 0.6121 - val_acc: 0.7937
# Epoch 76/300
# 8/8 [==============================] - 2s 301ms/step - loss: 0.6254 - acc: 0.7910 - val_loss: 0.5947 - val_acc: 0.8062
# Epoch 77/300
# 8/8 [==============================] - 2s 306ms/step - loss: 0.6598 - acc: 0.7849 - val_loss: 0.5868 - val_acc: 0.8156
# Epoch 78/300
# 8/8 [==============================] - 3s 317ms/step - loss: 0.5923 - acc: 0.8025 - val_loss: 0.5779 - val_acc: 0.8094
# Epoch 79/300
# 8/8 [==============================] - 3s 331ms/step - loss: 0.5541 - acc: 0.8092 - val_loss: 0.5655 - val_acc: 0.8250
# Epoch 80/300
# 8/8 [==============================] - 3s 331ms/step - loss: 0.6147 - acc: 0.8047 - val_loss: 0.6212 - val_acc: 0.8188
# Epoch 81/300
# 8/8 [==============================] - 3s 319ms/step - loss: 0.6180 - acc: 0.8042 - val_loss: 0.5993 - val_acc: 0.8094
# Epoch 82/300
# 8/8 [==============================] - 2s 308ms/step - loss: 0.6180 - acc: 0.7910 - val_loss: 0.5729 - val_acc: 0.8156
# Epoch 83/300
# 8/8 [==============================] - 3s 312ms/step - loss: 0.5760 - acc: 0.8081 - val_loss: 0.6101 - val_acc: 0.8125
# Epoch 84/300
# 8/8 [==============================] - 2s 310ms/step - loss: 0.6003 - acc: 0.8064 - val_loss: 0.5665 - val_acc: 0.8188
# Epoch 85/300
# 8/8 [==============================] - 2s 307ms/step - loss: 0.5780 - acc: 0.8136 - val_loss: 0.5622 - val_acc: 0.8344
# Epoch 86/300
# 8/8 [==============================] - 2s 307ms/step - loss: 0.6224 - acc: 0.8042 - val_loss: 0.5771 - val_acc: 0.8344
# Epoch 87/300
# 8/8 [==============================] - 2s 313ms/step - loss: 0.5570 - acc: 0.8207 - val_loss: 0.5695 - val_acc: 0.8406
# Epoch 88/300
# 8/8 [==============================] - 2s 305ms/step - loss: 0.5625 - acc: 0.8125 - val_loss: 0.5587 - val_acc: 0.8281
# Epoch 89/300
# 8/8 [==============================] - 2s 305ms/step - loss: 0.6206 - acc: 0.8053 - val_loss: 0.5900 - val_acc: 0.8344
# Epoch 90/300
# 8/8 [==============================] - 3s 315ms/step - loss: 0.5595 - acc: 0.8180 - val_loss: 0.5491 - val_acc: 0.8344
# Epoch 91/300
# 8/8 [==============================] - 2s 314ms/step - loss: 0.5557 - acc: 0.8279 - val_loss: 0.5799 - val_acc: 0.8125
# Epoch 92/300
# 8/8 [==============================] - 3s 327ms/step - loss: 0.5702 - acc: 0.8047 - val_loss: 0.5733 - val_acc: 0.8281
# Epoch 93/300
# 8/8 [==============================] - 2s 308ms/step - loss: 0.5658 - acc: 0.8130 - val_loss: 0.5744 - val_acc: 0.8219
# Epoch 94/300
# 8/8 [==============================] - 2s 310ms/step - loss: 0.5216 - acc: 0.8274 - val_loss: 0.5427 - val_acc: 0.8375
# Epoch 95/300
# 8/8 [==============================] - 2s 309ms/step - loss: 0.5275 - acc: 0.8345 - val_loss: 0.6004 - val_acc: 0.8250
# Epoch 96/300
# 8/8 [==============================] - 2s 308ms/step - loss: 0.5323 - acc: 0.8263 - val_loss: 0.6130 - val_acc: 0.8219
# Epoch 97/300
# 8/8 [==============================] - 2s 313ms/step - loss: 0.5291 - acc: 0.8240 - val_loss: 0.5654 - val_acc: 0.8313
# Epoch 98/300
# 8/8 [==============================] - 3s 329ms/step - loss: 0.5450 - acc: 0.8285 - val_loss: 0.5511 - val_acc: 0.8375
# Epoch 99/300
# 8/8 [==============================] - 3s 320ms/step - loss: 0.5530 - acc: 0.8224 - val_loss: 0.5665 - val_acc: 0.8344
# Epoch 100/300
# 8/8 [==============================] - 2s 307ms/step - loss: 0.5857 - acc: 0.8058 - val_loss: 0.6069 - val_acc: 0.8281
# Epoch 101/300
# 8/8 [==============================] - 3s 315ms/step - loss: 0.5530 - acc: 0.8185 - val_loss: 0.6102 - val_acc: 0.8062
# Epoch 102/300
# 8/8 [==============================] - 2s 312ms/step - loss: 0.5312 - acc: 0.8367 - val_loss: 0.5593 - val_acc: 0.8438
# Epoch 103/300
# 8/8 [==============================] - 2s 314ms/step - loss: 0.5190 - acc: 0.8356 - val_loss: 0.5814 - val_acc: 0.8375
# Epoch 104/300
# 8/8 [==============================] - 2s 309ms/step - loss: 0.5365 - acc: 0.8257 - val_loss: 0.5931 - val_acc: 0.8375
# Epoch 105/300
# 8/8 [==============================] - 3s 318ms/step - loss: 0.5410 - acc: 0.8345 - val_loss: 0.6093 - val_acc: 0.8281
# Epoch 106/300
# 8/8 [==============================] - 2s 308ms/step - loss: 0.4768 - acc: 0.8500 - val_loss: 0.6430 - val_acc: 0.8219
# Epoch 107/300
# 8/8 [==============================] - 3s 323ms/step - loss: 0.4941 - acc: 0.8406 - val_loss: 0.6462 - val_acc: 0.8062
# Epoch 108/300
# 8/8 [==============================] - 2s 303ms/step - loss: 0.4955 - acc: 0.8406 - val_loss: 0.6019 - val_acc: 0.8375
# Epoch 109/300
# 8/8 [==============================] - 2s 303ms/step - loss: 0.5148 - acc: 0.8351 - val_loss: 0.6438 - val_acc: 0.8406
# Epoch 110/300
# 8/8 [==============================] - 2s 310ms/step - loss: 0.5117 - acc: 0.8345 - val_loss: 0.6322 - val_acc: 0.8375
# Epoch 111/300
# 8/8 [==============================] - 2s 300ms/step - loss: 0.5038 - acc: 0.8467 - val_loss: 0.5766 - val_acc: 0.8438
# Epoch 112/300
# 8/8 [==============================] - 2s 301ms/step - loss: 0.4708 - acc: 0.8538 - val_loss: 0.5564 - val_acc: 0.8438
# Epoch 113/300
# 8/8 [==============================] - 2s 302ms/step - loss: 0.4900 - acc: 0.8373 - val_loss: 0.5796 - val_acc: 0.8375
# Epoch 114/300
# 8/8 [==============================] - 2s 304ms/step - loss: 0.4747 - acc: 0.8527 - val_loss: 0.6014 - val_acc: 0.8313
# Epoch 115/300
# 8/8 [==============================] - 2s 304ms/step - loss: 0.4750 - acc: 0.8472 - val_loss: 0.5662 - val_acc: 0.8531
# Epoch 116/300
# 8/8 [==============================] - 2s 305ms/step - loss: 0.4964 - acc: 0.8389 - val_loss: 0.5434 - val_acc: 0.8500
# Epoch 117/300
# 8/8 [==============================] - 2s 303ms/step - loss: 0.4943 - acc: 0.8395 - val_loss: 0.5528 - val_acc: 0.8500
# Epoch 118/300
# 8/8 [==============================] - 2s 302ms/step - loss: 0.4899 - acc: 0.8445 - val_loss: 0.5515 - val_acc: 0.8469
# Epoch 119/300
# 8/8 [==============================] - 2s 308ms/step - loss: 0.4994 - acc: 0.8434 - val_loss: 0.5609 - val_acc: 0.8469
# Epoch 120/300
# 8/8 [==============================] - 2s 305ms/step - loss: 0.5037 - acc: 0.8478 - val_loss: 0.5638 - val_acc: 0.8469
# Epoch 121/300
# 8/8 [==============================] - 2s 300ms/step - loss: 0.4467 - acc: 0.8649 - val_loss: 0.5501 - val_acc: 0.8500
# Epoch 122/300
# 8/8 [==============================] - 2s 303ms/step - loss: 0.4825 - acc: 0.8478 - val_loss: 0.5584 - val_acc: 0.8531
# Epoch 123/300
# 8/8 [==============================] - 2s 303ms/step - loss: 0.4717 - acc: 0.8478 - val_loss: 0.5500 - val_acc: 0.8531
# Epoch 124/300
# 8/8 [==============================] - 2s 306ms/step - loss: 0.4922 - acc: 0.8456 - val_loss: 0.5479 - val_acc: 0.8531
# Epoch 125/300
# 8/8 [==============================] - 2s 304ms/step - loss: 0.4671 - acc: 0.8483 - val_loss: 0.5565 - val_acc: 0.8562
# Epoch 126/300
# 8/8 [==============================] - 2s 304ms/step - loss: 0.4816 - acc: 0.8423 - val_loss: 0.5656 - val_acc: 0.8531
# Epoch 127/300
# 8/8 [==============================] - 2s 310ms/step - loss: 0.4617 - acc: 0.8593 - val_loss: 0.5686 - val_acc: 0.8438
# Epoch 128/300
# 8/8 [==============================] - 2s 309ms/step - loss: 0.4922 - acc: 0.8417 - val_loss: 0.5579 - val_acc: 0.8406
# Epoch 129/300
# 8/8 [==============================] - 2s 314ms/step - loss: 0.4900 - acc: 0.8483 - val_loss: 0.5865 - val_acc: 0.8500
# Epoch 130/300
# 8/8 [==============================] - 2s 301ms/step - loss: 0.4849 - acc: 0.8533 - val_loss: 0.5956 - val_acc: 0.8375
# Epoch 131/300
# 8/8 [==============================] - 2s 314ms/step - loss: 0.4809 - acc: 0.8439 - val_loss: 0.6117 - val_acc: 0.8281
# Epoch 132/300
# 8/8 [==============================] - 3s 314ms/step - loss: 0.5098 - acc: 0.8483 - val_loss: 0.5758 - val_acc: 0.8438
# Epoch 133/300
# 8/8 [==============================] - 3s 322ms/step - loss: 0.4844 - acc: 0.8516 - val_loss: 0.5587 - val_acc: 0.8469
# Epoch 134/300
# 8/8 [==============================] - 2s 309ms/step - loss: 0.4731 - acc: 0.8533 - val_loss: 0.5582 - val_acc: 0.8562
# Epoch 135/300
# 8/8 [==============================] - 2s 310ms/step - loss: 0.4660 - acc: 0.8544 - val_loss: 0.5426 - val_acc: 0.8656
# Epoch 136/300
# 8/8 [==============================] - 2s 302ms/step - loss: 0.4677 - acc: 0.8610 - val_loss: 0.5496 - val_acc: 0.8656
# Epoch 137/300
# 8/8 [==============================] - 2s 308ms/step - loss: 0.4503 - acc: 0.8527 - val_loss: 0.5877 - val_acc: 0.8469
# Epoch 138/300
# 8/8 [==============================] - 2s 303ms/step - loss: 0.4717 - acc: 0.8500 - val_loss: 0.6021 - val_acc: 0.8438
# Epoch 139/300
# 8/8 [==============================] - 2s 308ms/step - loss: 0.4504 - acc: 0.8616 - val_loss: 0.5548 - val_acc: 0.8500
# Epoch 140/300
# 8/8 [==============================] - 2s 304ms/step - loss: 0.4937 - acc: 0.8428 - val_loss: 0.5473 - val_acc: 0.8594
# Epoch 141/300
# 8/8 [==============================] - 2s 303ms/step - loss: 0.4462 - acc: 0.8610 - val_loss: 0.5305 - val_acc: 0.8594
# Epoch 142/300
# 8/8 [==============================] - 2s 300ms/step - loss: 0.4545 - acc: 0.8577 - val_loss: 0.5302 - val_acc: 0.8500
# Epoch 143/300
# 8/8 [==============================] - 2s 310ms/step - loss: 0.4622 - acc: 0.8638 - val_loss: 0.5339 - val_acc: 0.8500
# Epoch 144/300
# 8/8 [==============================] - 2s 305ms/step - loss: 0.4566 - acc: 0.8544 - val_loss: 0.5299 - val_acc: 0.8594
# Epoch 145/300
# 8/8 [==============================] - 2s 308ms/step - loss: 0.4571 - acc: 0.8571 - val_loss: 0.5485 - val_acc: 0.8594
# Epoch 146/300
# 8/8 [==============================] - 2s 312ms/step - loss: 0.4345 - acc: 0.8643 - val_loss: 0.5524 - val_acc: 0.8625
# Epoch 147/300
# 8/8 [==============================] - 3s 327ms/step - loss: 0.4052 - acc: 0.8753 - val_loss: 0.5988 - val_acc: 0.8406
# Epoch 148/300
# 8/8 [==============================] - 3s 319ms/step - loss: 0.4367 - acc: 0.8687 - val_loss: 0.6305 - val_acc: 0.8375
# Epoch 149/300
# 8/8 [==============================] - 2s 305ms/step - loss: 0.4568 - acc: 0.8649 - val_loss: 0.6052 - val_acc: 0.8344
# Epoch 150/300
# 8/8 [==============================] - 2s 305ms/step - loss: 0.4430 - acc: 0.8660 - val_loss: 0.6022 - val_acc: 0.8406
# Epoch 151/300
# 8/8 [==============================] - 2s 313ms/step - loss: 0.4595 - acc: 0.8549 - val_loss: 0.6459 - val_acc: 0.8281
# Epoch 152/300
# 8/8 [==============================] - 2s 314ms/step - loss: 0.4484 - acc: 0.8682 - val_loss: 0.5895 - val_acc: 0.8469
# Epoch 153/300
# 8/8 [==============================] - 2s 308ms/step - loss: 0.4466 - acc: 0.8643 - val_loss: 0.5540 - val_acc: 0.8469
# Epoch 154/300
# 8/8 [==============================] - 2s 308ms/step - loss: 0.4911 - acc: 0.8478 - val_loss: 0.5640 - val_acc: 0.8406
# Epoch 155/300
# 8/8 [==============================] - 2s 304ms/step - loss: 0.4803 - acc: 0.8560 - val_loss: 0.5793 - val_acc: 0.8438
# Epoch 156/300
# 8/8 [==============================] - 2s 309ms/step - loss: 0.3892 - acc: 0.8831 - val_loss: 0.5383 - val_acc: 0.8500
# Epoch 157/300
# 8/8 [==============================] - 2s 307ms/step - loss: 0.4727 - acc: 0.8527 - val_loss: 0.5343 - val_acc: 0.8594
# Epoch 158/300
# 8/8 [==============================] - 2s 304ms/step - loss: 0.4606 - acc: 0.8599 - val_loss: 0.5957 - val_acc: 0.8406
# Epoch 159/300
# 8/8 [==============================] - 2s 313ms/step - loss: 0.4592 - acc: 0.8489 - val_loss: 0.5533 - val_acc: 0.8438
# Epoch 160/300
# 8/8 [==============================] - 2s 309ms/step - loss: 0.4666 - acc: 0.8516 - val_loss: 0.5757 - val_acc: 0.8344
# Epoch 161/300
# 8/8 [==============================] - 2s 304ms/step - loss: 0.4640 - acc: 0.8461 - val_loss: 0.5985 - val_acc: 0.8313
# Epoch 162/300
# 8/8 [==============================] - 2s 305ms/step - loss: 0.4179 - acc: 0.8709 - val_loss: 0.5703 - val_acc: 0.8406
# Epoch 163/300
# 8/8 [==============================] - 2s 306ms/step - loss: 0.4377 - acc: 0.8649 - val_loss: 0.5804 - val_acc: 0.8375
# Epoch 164/300
# 8/8 [==============================] - 2s 304ms/step - loss: 0.4294 - acc: 0.8704 - val_loss: 0.6247 - val_acc: 0.8281
# Epoch 165/300
# 8/8 [==============================] - 2s 306ms/step - loss: 0.4286 - acc: 0.8643 - val_loss: 0.5799 - val_acc: 0.8344
# Epoch 166/300
# 8/8 [==============================] - 2s 304ms/step - loss: 0.4151 - acc: 0.8627 - val_loss: 0.6360 - val_acc: 0.8344
# Epoch 167/300
# 8/8 [==============================] - 2s 303ms/step - loss: 0.4311 - acc: 0.8654 - val_loss: 0.6388 - val_acc: 0.8281
# Epoch 168/300
# 8/8 [==============================] - 2s 300ms/step - loss: 0.3957 - acc: 0.8759 - val_loss: 0.5795 - val_acc: 0.8344
# Epoch 169/300
# 8/8 [==============================] - 2s 301ms/step - loss: 0.4145 - acc: 0.8720 - val_loss: 0.5609 - val_acc: 0.8375
# Epoch 170/300
# 8/8 [==============================] - 2s 306ms/step - loss: 0.4181 - acc: 0.8649 - val_loss: 0.5849 - val_acc: 0.8406
# Epoch 171/300
# 8/8 [==============================] - 2s 303ms/step - loss: 0.4184 - acc: 0.8660 - val_loss: 0.5836 - val_acc: 0.8469
# Epoch 172/300
# 8/8 [==============================] - 2s 304ms/step - loss: 0.4276 - acc: 0.8643 - val_loss: 0.5800 - val_acc: 0.8531
# Epoch 173/300
# 8/8 [==============================] - 2s 300ms/step - loss: 0.4577 - acc: 0.8616 - val_loss: 0.5673 - val_acc: 0.8531
# Epoch 174/300
# 8/8 [==============================] - 2s 303ms/step - loss: 0.3859 - acc: 0.8809 - val_loss: 0.5638 - val_acc: 0.8531
# Epoch 175/300
# 8/8 [==============================] - 2s 304ms/step - loss: 0.4077 - acc: 0.8764 - val_loss: 0.5608 - val_acc: 0.8562
# Epoch 176/300
# 8/8 [==============================] - 2s 310ms/step - loss: 0.4392 - acc: 0.8660 - val_loss: 0.5720 - val_acc: 0.8469
# Epoch 177/300
# 8/8 [==============================] - 2s 306ms/step - loss: 0.4395 - acc: 0.8665 - val_loss: 0.5596 - val_acc: 0.8406
# Epoch 178/300
# 8/8 [==============================] - 2s 315ms/step - loss: 0.4582 - acc: 0.8560 - val_loss: 0.5522 - val_acc: 0.8625
# Epoch 179/300
# 8/8 [==============================] - 2s 308ms/step - loss: 0.4191 - acc: 0.8649 - val_loss: 0.5486 - val_acc: 0.8500
# Epoch 180/300
# 8/8 [==============================] - 2s 310ms/step - loss: 0.4031 - acc: 0.8704 - val_loss: 0.5660 - val_acc: 0.8406
# Epoch 181/300
# 8/8 [==============================] - 2s 309ms/step - loss: 0.3903 - acc: 0.8731 - val_loss: 0.5725 - val_acc: 0.8687
# Epoch 182/300
# 8/8 [==============================] - 2s 302ms/step - loss: 0.3986 - acc: 0.8731 - val_loss: 0.5562 - val_acc: 0.8656
# Epoch 183/300
# 8/8 [==============================] - 2s 306ms/step - loss: 0.4277 - acc: 0.8715 - val_loss: 0.5731 - val_acc: 0.8594
# Epoch 184/300
# 8/8 [==============================] - 2s 305ms/step - loss: 0.4530 - acc: 0.8577 - val_loss: 0.5388 - val_acc: 0.8562
# Epoch 185/300
# 8/8 [==============================] - 2s 302ms/step - loss: 0.4276 - acc: 0.8665 - val_loss: 0.5483 - val_acc: 0.8625
# Epoch 186/300
# 8/8 [==============================] - 2s 303ms/step - loss: 0.4149 - acc: 0.8676 - val_loss: 0.5508 - val_acc: 0.8625
# Epoch 187/300
# 8/8 [==============================] - 2s 302ms/step - loss: 0.4240 - acc: 0.8671 - val_loss: 0.5691 - val_acc: 0.8562
# Epoch 188/300
# 8/8 [==============================] - 2s 306ms/step - loss: 0.4221 - acc: 0.8638 - val_loss: 0.5367 - val_acc: 0.8625
# Epoch 189/300
# 8/8 [==============================] - 2s 305ms/step - loss: 0.4264 - acc: 0.8671 - val_loss: 0.5569 - val_acc: 0.8656
# Epoch 190/300
# 8/8 [==============================] - 2s 307ms/step - loss: 0.4121 - acc: 0.8698 - val_loss: 0.5952 - val_acc: 0.8406
# Epoch 191/300
# 8/8 [==============================] - 2s 302ms/step - loss: 0.4540 - acc: 0.8593 - val_loss: 0.6422 - val_acc: 0.8344
# Epoch 192/300
# 8/8 [==============================] - 2s 301ms/step - loss: 0.4486 - acc: 0.8571 - val_loss: 0.5654 - val_acc: 0.8625
# Epoch 193/300
# 8/8 [==============================] - 2s 306ms/step - loss: 0.4291 - acc: 0.8643 - val_loss: 0.5536 - val_acc: 0.8656
# Epoch 194/300
# 8/8 [==============================] - 2s 304ms/step - loss: 0.4034 - acc: 0.8770 - val_loss: 0.5386 - val_acc: 0.8687
# Epoch 195/300
# 8/8 [==============================] - 2s 304ms/step - loss: 0.4031 - acc: 0.8787 - val_loss: 0.5383 - val_acc: 0.8625
# Epoch 196/300
# 8/8 [==============================] - 2s 308ms/step - loss: 0.4393 - acc: 0.8698 - val_loss: 0.5291 - val_acc: 0.8531
# Epoch 197/300
# 8/8 [==============================] - 2s 308ms/step - loss: 0.4165 - acc: 0.8632 - val_loss: 0.5333 - val_acc: 0.8656
# Epoch 198/300
# 8/8 [==============================] - 2s 311ms/step - loss: 0.4298 - acc: 0.8616 - val_loss: 0.5234 - val_acc: 0.8531
# Epoch 199/300
# 8/8 [==============================] - 3s 316ms/step - loss: 0.4372 - acc: 0.8599 - val_loss: 0.5062 - val_acc: 0.8719
# Epoch 200/300
# 8/8 [==============================] - 3s 321ms/step - loss: 0.3908 - acc: 0.8787 - val_loss: 0.5424 - val_acc: 0.8656
# Epoch 201/300
# 8/8 [==============================] - 3s 339ms/step - loss: 0.4123 - acc: 0.8698 - val_loss: 0.5468 - val_acc: 0.8656
# Epoch 202/300
# 8/8 [==============================] - 3s 346ms/step - loss: 0.4115 - acc: 0.8748 - val_loss: 0.5525 - val_acc: 0.8594
# Epoch 203/300
# 8/8 [==============================] - 3s 327ms/step - loss: 0.3843 - acc: 0.8798 - val_loss: 0.5503 - val_acc: 0.8500
# Epoch 204/300
# 8/8 [==============================] - 2s 308ms/step - loss: 0.4039 - acc: 0.8704 - val_loss: 0.5582 - val_acc: 0.8438
# Epoch 205/300
# 8/8 [==============================] - 2s 309ms/step - loss: 0.4209 - acc: 0.8643 - val_loss: 0.5574 - val_acc: 0.8562
# Epoch 206/300
# 8/8 [==============================] - 2s 312ms/step - loss: 0.4135 - acc: 0.8748 - val_loss: 0.5646 - val_acc: 0.8562
# Epoch 207/300
# 8/8 [==============================] - 2s 303ms/step - loss: 0.4299 - acc: 0.8632 - val_loss: 0.5788 - val_acc: 0.8469
# Epoch 208/300
# 8/8 [==============================] - 2s 306ms/step - loss: 0.3872 - acc: 0.8836 - val_loss: 0.5499 - val_acc: 0.8469
# Epoch 209/300
# 8/8 [==============================] - 2s 300ms/step - loss: 0.4053 - acc: 0.8776 - val_loss: 0.5602 - val_acc: 0.8625
# Epoch 210/300
# 8/8 [==============================] - 2s 299ms/step - loss: 0.3966 - acc: 0.8825 - val_loss: 0.5490 - val_acc: 0.8687
# Epoch 211/300
# 8/8 [==============================] - 2s 302ms/step - loss: 0.4060 - acc: 0.8742 - val_loss: 0.6033 - val_acc: 0.8469
# Epoch 212/300
# 8/8 [==============================] - 2s 304ms/step - loss: 0.4200 - acc: 0.8770 - val_loss: 0.5805 - val_acc: 0.8500
# Epoch 213/300
# 8/8 [==============================] - 2s 304ms/step - loss: 0.4123 - acc: 0.8665 - val_loss: 0.5735 - val_acc: 0.8500
# Epoch 214/300
# 8/8 [==============================] - 3s 315ms/step - loss: 0.3788 - acc: 0.8770 - val_loss: 0.5573 - val_acc: 0.8625
# Epoch 215/300
# 8/8 [==============================] - 2s 313ms/step - loss: 0.4023 - acc: 0.8764 - val_loss: 0.5642 - val_acc: 0.8656
# Epoch 216/300
# 8/8 [==============================] - 2s 302ms/step - loss: 0.3798 - acc: 0.8886 - val_loss: 0.5693 - val_acc: 0.8656
# Epoch 217/300
# 8/8 [==============================] - 2s 304ms/step - loss: 0.4135 - acc: 0.8787 - val_loss: 0.5654 - val_acc: 0.8625
# Epoch 218/300
# 8/8 [==============================] - 2s 304ms/step - loss: 0.3434 - acc: 0.8946 - val_loss: 0.5765 - val_acc: 0.8625
# Epoch 219/300
# 8/8 [==============================] - 2s 307ms/step - loss: 0.3837 - acc: 0.8825 - val_loss: 0.5805 - val_acc: 0.8687
# Epoch 220/300
# 8/8 [==============================] - 3s 318ms/step - loss: 0.3960 - acc: 0.8798 - val_loss: 0.5346 - val_acc: 0.8750
# Epoch 221/300
# 8/8 [==============================] - 3s 316ms/step - loss: 0.3825 - acc: 0.8858 - val_loss: 0.5246 - val_acc: 0.8719
# Epoch 222/300
# 8/8 [==============================] - 2s 312ms/step - loss: 0.3836 - acc: 0.8831 - val_loss: 0.5618 - val_acc: 0.8687
# Epoch 223/300
# 8/8 [==============================] - 2s 309ms/step - loss: 0.3909 - acc: 0.8759 - val_loss: 0.6147 - val_acc: 0.8562
# Epoch 224/300
# 8/8 [==============================] - 2s 302ms/step - loss: 0.3737 - acc: 0.8787 - val_loss: 0.5762 - val_acc: 0.8656
# Epoch 225/300
# 8/8 [==============================] - 2s 305ms/step - loss: 0.3659 - acc: 0.8825 - val_loss: 0.5874 - val_acc: 0.8500
# Epoch 226/300
# 8/8 [==============================] - 2s 311ms/step - loss: 0.4167 - acc: 0.8787 - val_loss: 0.6055 - val_acc: 0.8531
# Epoch 227/300
# 8/8 [==============================] - 2s 314ms/step - loss: 0.4034 - acc: 0.8748 - val_loss: 0.5734 - val_acc: 0.8531
# Epoch 228/300
# 8/8 [==============================] - 2s 305ms/step - loss: 0.3753 - acc: 0.8847 - val_loss: 0.5501 - val_acc: 0.8719
# Epoch 229/300
# 8/8 [==============================] - 2s 307ms/step - loss: 0.4143 - acc: 0.8682 - val_loss: 0.5462 - val_acc: 0.8687
# Epoch 230/300
# 8/8 [==============================] - 2s 304ms/step - loss: 0.3548 - acc: 0.8913 - val_loss: 0.5755 - val_acc: 0.8594
# Epoch 231/300
# 8/8 [==============================] - 2s 304ms/step - loss: 0.3895 - acc: 0.8787 - val_loss: 0.5647 - val_acc: 0.8687
# Epoch 232/300
# 8/8 [==============================] - 2s 303ms/step - loss: 0.4043 - acc: 0.8753 - val_loss: 0.5319 - val_acc: 0.8625
# Epoch 233/300
# 8/8 [==============================] - 2s 305ms/step - loss: 0.4330 - acc: 0.8660 - val_loss: 0.5275 - val_acc: 0.8656
# Epoch 234/300
# 8/8 [==============================] - 2s 304ms/step - loss: 0.3973 - acc: 0.8731 - val_loss: 0.5541 - val_acc: 0.8562
# Epoch 235/300
# 8/8 [==============================] - 2s 305ms/step - loss: 0.3874 - acc: 0.8798 - val_loss: 0.5630 - val_acc: 0.8594
# Epoch 236/300
# 8/8 [==============================] - 2s 306ms/step - loss: 0.4012 - acc: 0.8742 - val_loss: 0.5483 - val_acc: 0.8687
# Epoch 237/300
# 8/8 [==============================] - 2s 309ms/step - loss: 0.4045 - acc: 0.8753 - val_loss: 0.5475 - val_acc: 0.8656
# Epoch 238/300
# 8/8 [==============================] - 2s 314ms/step - loss: 0.4303 - acc: 0.8676 - val_loss: 0.5283 - val_acc: 0.8719
# Epoch 239/300
# 8/8 [==============================] - 2s 313ms/step - loss: 0.3840 - acc: 0.8853 - val_loss: 0.5363 - val_acc: 0.8656
# Epoch 240/300
# 8/8 [==============================] - 2s 307ms/step - loss: 0.4092 - acc: 0.8764 - val_loss: 0.5459 - val_acc: 0.8594
# Epoch 241/300
# 8/8 [==============================] - 2s 313ms/step - loss: 0.3782 - acc: 0.8853 - val_loss: 0.5725 - val_acc: 0.8656
# Epoch 242/300
# 8/8 [==============================] - 2s 310ms/step - loss: 0.4136 - acc: 0.8776 - val_loss: 0.5991 - val_acc: 0.8625
# Epoch 243/300
# 8/8 [==============================] - 2s 306ms/step - loss: 0.3654 - acc: 0.8798 - val_loss: 0.5930 - val_acc: 0.8469
# Epoch 244/300
# 8/8 [==============================] - 2s 310ms/step - loss: 0.3595 - acc: 0.8820 - val_loss: 0.5941 - val_acc: 0.8531
# Epoch 245/300
# 8/8 [==============================] - 3s 321ms/step - loss: 0.3767 - acc: 0.8831 - val_loss: 0.6198 - val_acc: 0.8469
# Epoch 246/300
# 8/8 [==============================] - 2s 304ms/step - loss: 0.3853 - acc: 0.8803 - val_loss: 0.6039 - val_acc: 0.8562
# Epoch 247/300
# 8/8 [==============================] - 2s 308ms/step - loss: 0.3818 - acc: 0.8759 - val_loss: 0.5674 - val_acc: 0.8562
# Epoch 248/300
# 8/8 [==============================] - 2s 305ms/step - loss: 0.4061 - acc: 0.8748 - val_loss: 0.5389 - val_acc: 0.8656
# Epoch 249/300
# 8/8 [==============================] - 2s 309ms/step - loss: 0.4200 - acc: 0.8742 - val_loss: 0.5531 - val_acc: 0.8594
# Epoch 250/300
# 8/8 [==============================] - 2s 306ms/step - loss: 0.3555 - acc: 0.8858 - val_loss: 0.5972 - val_acc: 0.8469
# Epoch 251/300
# 8/8 [==============================] - 2s 310ms/step - loss: 0.3546 - acc: 0.8886 - val_loss: 0.5660 - val_acc: 0.8687
# Epoch 252/300
# 8/8 [==============================] - 2s 306ms/step - loss: 0.3732 - acc: 0.8847 - val_loss: 0.6128 - val_acc: 0.8469
# Epoch 253/300
# 8/8 [==============================] - 2s 305ms/step - loss: 0.4146 - acc: 0.8742 - val_loss: 0.6522 - val_acc: 0.8406
# Epoch 254/300
# 8/8 [==============================] - 2s 311ms/step - loss: 0.3982 - acc: 0.8715 - val_loss: 0.5909 - val_acc: 0.8469
# Epoch 255/300
# 8/8 [==============================] - 2s 304ms/step - loss: 0.4050 - acc: 0.8748 - val_loss: 0.6187 - val_acc: 0.8438
# Epoch 256/300
# 8/8 [==============================] - 2s 306ms/step - loss: 0.3834 - acc: 0.8764 - val_loss: 0.6542 - val_acc: 0.8500
# Epoch 257/300
# 8/8 [==============================] - 2s 306ms/step - loss: 0.3359 - acc: 0.8963 - val_loss: 0.6331 - val_acc: 0.8500
# Epoch 258/300
# 8/8 [==============================] - 2s 304ms/step - loss: 0.3613 - acc: 0.8946 - val_loss: 0.6379 - val_acc: 0.8531
# Epoch 259/300
# 8/8 [==============================] - 2s 302ms/step - loss: 0.3645 - acc: 0.8908 - val_loss: 0.6034 - val_acc: 0.8594
# Epoch 260/300
# 8/8 [==============================] - 2s 303ms/step - loss: 0.3442 - acc: 0.8935 - val_loss: 0.5817 - val_acc: 0.8750
# Epoch 261/300
# 8/8 [==============================] - 2s 307ms/step - loss: 0.3675 - acc: 0.8875 - val_loss: 0.5948 - val_acc: 0.8687
# Epoch 262/300
# 8/8 [==============================] - 2s 304ms/step - loss: 0.3881 - acc: 0.8809 - val_loss: 0.5982 - val_acc: 0.8687
# Epoch 263/300
# 8/8 [==============================] - 2s 304ms/step - loss: 0.3601 - acc: 0.8864 - val_loss: 0.5964 - val_acc: 0.8531
# Epoch 264/300
# 8/8 [==============================] - 2s 301ms/step - loss: 0.3541 - acc: 0.8875 - val_loss: 0.5833 - val_acc: 0.8531
# Epoch 265/300
# 8/8 [==============================] - 2s 305ms/step - loss: 0.3436 - acc: 0.9007 - val_loss: 0.5647 - val_acc: 0.8500
# Epoch 266/300
# 8/8 [==============================] - 2s 307ms/step - loss: 0.3700 - acc: 0.8958 - val_loss: 0.5724 - val_acc: 0.8562
# Epoch 267/300
# 8/8 [==============================] - 2s 307ms/step - loss: 0.3329 - acc: 0.8913 - val_loss: 0.5924 - val_acc: 0.8531
# Epoch 268/300
# 8/8 [==============================] - 2s 307ms/step - loss: 0.3890 - acc: 0.8753 - val_loss: 0.6240 - val_acc: 0.8531
# Epoch 269/300
# 8/8 [==============================] - 2s 308ms/step - loss: 0.4452 - acc: 0.8671 - val_loss: 0.5902 - val_acc: 0.8656
# Epoch 270/300
# 8/8 [==============================] - 2s 307ms/step - loss: 0.4160 - acc: 0.8809 - val_loss: 0.5480 - val_acc: 0.8562

# %% [markdown]
# Let's plot the learning curves

# %%
display_learning_curves(history)

# %% [markdown]
# Now we evaluate the GNN model on the test data split.
# The results may vary depending on the training sample, however the GNN model always outperforms
# the baseline model in terms of the test accuracy.

# %%
X_test = test_data.paper_id.to_numpy()
_, test_accuracy = gnn_model.evaluate(x=X_test, y=Y_test, verbose=0)
print(f"Test accuracy: {round(test_accuracy * 100, 2)}%")
# Out:
# Test accuracy: 88.52%
